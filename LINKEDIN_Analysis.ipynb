# %% [markdown]
# #This notebook contains LinkedIn analysis using connect.csv without LinkedIn API and Geocode API key
#
# > Profile Analysis
#
# > Clustering Job Titles

# %% [markdown]
# #**Profile Analysis**

# %%
import os
import csv
import numpy as np

# Point this to your 'Connections.csv' file.
CSV_FILE = os.path.join('resources', 'ch04-linkedin', 'Connections.csv')

csvReader = csv.DictReader(open("/content/Connections.csv"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# %% [markdown]
# ###Simple normalization of company suffixes from address book data

# %%
from prettytable import PrettyTable # pip install prettytable
from collections import Counter
from operator import itemgetter

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)

[pt.add_row([company, freq]) for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) if freq > 1]

print(pt)
# Out:
# +--------------------------------------------------+------+
# | Company                                          | Freq |
# +--------------------------------------------------+------+
# | Infosys                                          | 68   |
# | Wipro                                            | 4    |
# | Cognizant                                        | 3    |
# | MENMOZHI TECHNOLOGIES                            | 3    |
# | Deloitte                                         | 3    |
# | Accenture                                        | 3    |
# | Bishop Heber College, Tiruchirappalli - 620 017. | 3    |
# | Indian Institute of Technology, Madras           | 2    |
# | Microsoft                                        | 2    |
# | Tata Consultancy Services                        | 2    |
# | BYJU'S                                           | 2    |
# | The Sparks Foundation                            | 2    |
# | Zoho Corporation                                 | 2    |
# | Infosys Ltd                                      | 2    |
# +--------------------------------------------------+------+

# %% [markdown]
# ###Standardizing common job titles and computing their frequencies

# %%
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Job Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print(pt)
# Out:
# +-------------------------------------+------+
# | Job Title                           | Freq |
# +-------------------------------------+------+
# | System Engineer                     | 25   |
# | Senior System Engineer              | 17   |
# | Software Engineer                   | 5    |
# | Systems Engineer                    | 5    |
# | Data Scientist                      | 4    |
# | Data Engineer                       | 3    |
# | Technology Analyst                  | 3    |
# | Operations Executive                | 3    |
# | Software Developer                  | 2    |
# | Senior Software Engineer            | 2    |
# | Founder and Chief Executive Officer | 2    |
# | Data Analyst                        | 2    |
# | Analyst                             | 2    |
# | Test Engineer                       | 2    |
# | Associate Consultant                | 2    |
# | Business Analyst                    | 2    |
# | Application Development Analyst     | 2    |
# | Senior Systems Engineer             | 2    |
# | Guest Lecturer                      | 2    |
# +-------------------------------------+------+
# +--------------+------+
# | Token        | Freq |
# +--------------+------+
# | Engineer     | 74   |
# | System       | 43   |
# | Senior       | 36   |
# | Data         | 28   |
# | Analyst      | 23   |
# | Software     | 15   |
# | Associate    | 12   |
# | Executive    | 10   |
# | Intern       | 9    |
# | and          | 9    |
# | Consultant   | 9    |
# | Technology   | 9    |
# | Development  | 9    |
# | Scientist    | 8    |
# | Science      | 8    |
# | Business     | 8    |
# | Manager      | 8    |
# | Developer    | 7    |
# | Systems      | 7    |
# | Specialist   | 6    |
# | Learning     | 6    |
# | Operations   | 5    |
# | Technical    | 5    |
# | Founder      | 5    |
# | Scholar      | 4    |
# | Analytics    | 4    |
# | Director     | 4    |
# | Chief        | 4    |
# | Officer      | 4    |
# | Artificial   | 3    |
# | Intelligence | 3    |
# | Professor    | 3    |
# | Operation    | 3    |
# | Management   | 3    |
# | Student      | 3    |
# | Test         | 3    |
# | Lead         | 3    |
# | Advisor      | 2    |
# | Research     | 2    |
# | Digital      | 2    |
# | Marketing    | 2    |
# | Programmer   | 2    |
# | Academic     | 2    |
# | Assistant    | 2    |
# | Talent       | 2    |
# | Member       | 2    |
# | Staff        | 2    |
# | Vice         | 2    |
# | President    | 2    |
# | Principal    | 2    |
# | Trainee      | 2    |
# | Machine      | 2    |
# | trainee      | 2    |
# | Project      | 2    |
# | Applications | 2    |
# | Application  | 2    |
# | Guest        | 2    |
# | Lecturer     | 2    |
# +--------------+------+

# %% [markdown]
# ###Geocoding locations with Google Maps

# %% [markdown]
# NOTE:This section contains no locations bcoz there is no geocode generated

# %%
for i, c in enumerate(contacts):
    progress = '{0:3d} of {1:3d} - '.format(i+1,len(contacts))
    company = c['Company']
    try:
        location = g.geocode(company, exactly_one=True)
    except:
        print('... Failed to get a location for {0}'.format(company))
        location = None
    
    if location != None:
        c.update([('Location', location)])
        print(progress + company[:50] + ' -- ' + location.address)
    else:
        c.update([('Location', None)])
        print(progress + company[:50] + ' -- ' + 'Unknown Location')
# Out:
# ... Failed to get a location for Navabrind IT Solutions Pvt Ltd
#   1 of 233 - Navabrind IT Solutions Pvt Ltd -- Unknown Location
# ... Failed to get a location for Jio ( Veremax Technologies)
#   2 of 233 - Jio ( Veremax Technologies) -- Unknown Location
# ... Failed to get a location for
#   3 of 233 -  -- Unknown Location
# ... Failed to get a location for DataRobot
#   4 of 233 - DataRobot -- Unknown Location
# ... Failed to get a location for Databand.ai
#   5 of 233 - Databand.ai -- Unknown Location
# ... Failed to get a location for Barclays
#   6 of 233 - Barclays -- Unknown Location
# ... Failed to get a location for NOBORDER.z
#   7 of 233 - NOBORDER.z -- Unknown Location
# ... Failed to get a location for Qicstart
#   8 of 233 - Qicstart -- Unknown Location
# ... Failed to get a location for Indian Institute of Technology, Madras
#   9 of 233 - Indian Institute of Technology, Madras -- Unknown Location
# ... Failed to get a location for Azzure
#  10 of 233 - Azzure -- Unknown Location
# ... Failed to get a location for Crompton Greaves Consumer Electricals Limited
#  11 of 233 - Crompton Greaves Consumer Electricals Limited -- Unknown Location
# ... Failed to get a location for Vellore Institute of Technology
#  12 of 233 - Vellore Institute of Technology -- Unknown Location
# ... Failed to get a location for Self-employed
#  13 of 233 - Self-employed -- Unknown Location
# ... Failed to get a location for Spinny
#  14 of 233 - Spinny -- Unknown Location
# ... Failed to get a location for Cognizant
#  15 of 233 - Cognizant -- Unknown Location
# ... Failed to get a location for Bank of America
#  16 of 233 - Bank of America -- Unknown Location
# ... Failed to get a location for Coforge
#  17 of 233 - Coforge -- Unknown Location
# ... Failed to get a location for Apple
#  18 of 233 - Apple -- Unknown Location
# ... Failed to get a location for Infosys
#  19 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Stealth Mode Startup Company
#  20 of 233 - Stealth Mode Startup Company -- Unknown Location
# ... Failed to get a location for Microsoft
#  21 of 233 - Microsoft -- Unknown Location
# ... Failed to get a location for Altus Health Care Solutions
#  22 of 233 - Altus Health Care Solutions -- Unknown Location
# ... Failed to get a location for Rkinformatics pvt ltd
#  23 of 233 - Rkinformatics pvt ltd -- Unknown Location
# ... Failed to get a location for Muthayammal College of Arts & Science
#  24 of 233 - Muthayammal College of Arts & Science -- Unknown Location
# ... Failed to get a location for Malaysian Communications and Multimedia Commission
#  25 of 233 - Malaysian Communications and Multimedia Commission -- Unknown Location
# ... Failed to get a location for Noble Transformation Hub (Ai)
#  26 of 233 - Noble Transformation Hub (Ai) -- Unknown Location
# ... Failed to get a location for Aram Visas
#  27 of 233 - Aram Visas -- Unknown Location
# ... Failed to get a location for Indian Institute of Technology, Madras
#  28 of 233 - Indian Institute of Technology, Madras -- Unknown Location
# ... Failed to get a location for
#  29 of 233 -  -- Unknown Location
# ... Failed to get a location for Walmart Global Tech India
#  30 of 233 - Walmart Global Tech India -- Unknown Location
# ... Failed to get a location for Zep Analytics
#  31 of 233 - Zep Analytics -- Unknown Location
# ... Failed to get a location for Zoho
#  32 of 233 - Zoho -- Unknown Location
# ... Failed to get a location for Infosys
#  33 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Cognizant
#  34 of 233 - Cognizant -- Unknown Location
# ... Failed to get a location for Capgemini
#  35 of 233 - Capgemini -- Unknown Location
# ... Failed to get a location for Algonomy
#  36 of 233 - Algonomy -- Unknown Location
# ... Failed to get a location for NTUC Enterprise Co-operative Limited
#  37 of 233 - NTUC Enterprise Co-operative Limited -- Unknown Location
# ... Failed to get a location for HSBC
#  38 of 233 - HSBC -- Unknown Location
# ... Failed to get a location for Evolution Recruitment Solutions, USA
#  39 of 233 - Evolution Recruitment Solutions, USA -- Unknown Location
# ... Failed to get a location for Shyena Tech Yarns Pvt Ltd
#  40 of 233 - Shyena Tech Yarns Pvt Ltd -- Unknown Location
# ... Failed to get a location for MENMOZHI TECHNOLOGIES
#  41 of 233 - MENMOZHI TECHNOLOGIES -- Unknown Location
# ... Failed to get a location for Analytics Saves at Work
#  42 of 233 - Analytics Saves at Work -- Unknown Location
# ... Failed to get a location for The Center of Applied Data Science
#  43 of 233 - The Center of Applied Data Science -- Unknown Location
# ... Failed to get a location for TagBox
#  44 of 233 - TagBox -- Unknown Location
# ... Failed to get a location for Freelance
#  45 of 233 - Freelance -- Unknown Location
# ... Failed to get a location for LTI - Larsen & Toubro Infotech
#  46 of 233 - LTI - Larsen & Toubro Infotech -- Unknown Location
# ... Failed to get a location for MSD
#  47 of 233 - MSD -- Unknown Location
# ... Failed to get a location for Infosys
#  48 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for HSIN
#  49 of 233 - HSIN -- Unknown Location
# ... Failed to get a location for Synechron
#  50 of 233 - Synechron -- Unknown Location
# ... Failed to get a location for CGI
#  51 of 233 - CGI -- Unknown Location
# ... Failed to get a location for Tata Consultancy Services
#  52 of 233 - Tata Consultancy Services -- Unknown Location
# ... Failed to get a location for Actify Data Labs
#  53 of 233 - Actify Data Labs -- Unknown Location
# ... Failed to get a location for IELEKTRON TECHNOLOGIES PVT. LTD.
#  54 of 233 - IELEKTRON TECHNOLOGIES PVT. LTD. -- Unknown Location
# ... Failed to get a location for Deloitte
#  55 of 233 - Deloitte -- Unknown Location
# ... Failed to get a location for THANTHAI ROEVER INSTITUTE OF AGRICULTURE AND RURAL DEVELOPMENT, PERAMBALUR
#  56 of 233 - THANTHAI ROEVER INSTITUTE OF AGRICULTURE AND RURAL -- Unknown Location
# ... Failed to get a location for Self-Employed
#  57 of 233 - Self-Employed -- Unknown Location
# ... Failed to get a location for
#  58 of 233 -  -- Unknown Location
# ... Failed to get a location for Infosys
#  59 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for
#  60 of 233 -  -- Unknown Location
# ... Failed to get a location for Success Enablers India
#  61 of 233 - Success Enablers India -- Unknown Location
# ... Failed to get a location for
#  62 of 233 -  -- Unknown Location
# ... Failed to get a location for
#  63 of 233 -  -- Unknown Location
# ... Failed to get a location for DXC Technology
#  64 of 233 - DXC Technology -- Unknown Location
# ... Failed to get a location for Vestige Marketing Pvt. Ltd.
#  65 of 233 - Vestige Marketing Pvt. Ltd. -- Unknown Location
# ... Failed to get a location for
#  66 of 233 -  -- Unknown Location
# ... Failed to get a location for
#  67 of 233 -  -- Unknown Location
# ... Failed to get a location for
#  68 of 233 -  -- Unknown Location
# ... Failed to get a location for UBS
#  69 of 233 - UBS -- Unknown Location
# ... Failed to get a location for Paytm
#  70 of 233 - Paytm -- Unknown Location
# ... Failed to get a location for
#  71 of 233 -  -- Unknown Location
# ... Failed to get a location for
#  72 of 233 -  -- Unknown Location
# ... Failed to get a location for
#  73 of 233 -  -- Unknown Location
# ... Failed to get a location for Wipro
#  74 of 233 - Wipro -- Unknown Location
# ... Failed to get a location for
#  75 of 233 -  -- Unknown Location
# ... Failed to get a location for Infosys
#  76 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for OptiSol Business Solutions
#  77 of 233 - OptiSol Business Solutions -- Unknown Location
# ... Failed to get a location for BYJU'S
#  78 of 233 - BYJU'S -- Unknown Location
# ... Failed to get a location for Merkle
#  79 of 233 - Merkle -- Unknown Location
# ... Failed to get a location for
#  80 of 233 -  -- Unknown Location
# ... Failed to get a location for The Sparks Foundation
#  81 of 233 - The Sparks Foundation -- Unknown Location
# ... Failed to get a location for Infosys
#  82 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Wipro Technologies
#  83 of 233 - Wipro Technologies  -- Unknown Location
# ... Failed to get a location for Infosys
#  84 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for EXL Health
#  85 of 233 - EXL Health -- Unknown Location
# ... Failed to get a location for Deloitte Consulting
#  86 of 233 - Deloitte Consulting -- Unknown Location
# ... Failed to get a location for
#  87 of 233 -  -- Unknown Location
# ... Failed to get a location for Worksbot Applications Private Limited
#  88 of 233 - Worksbot Applications Private Limited -- Unknown Location
# ... Failed to get a location for REGex Software Services
#  89 of 233 - REGex Software Services -- Unknown Location
# ... Failed to get a location for Vista
#  90 of 233 - Vista -- Unknown Location
# ... Failed to get a location for
#  91 of 233 -  -- Unknown Location
# ... Failed to get a location for Zoho Corporation
#  92 of 233 - Zoho Corporation -- Unknown Location
# ... Failed to get a location for
#  93 of 233 -  -- Unknown Location
# ... Failed to get a location for Infosys
#  94 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for MENMOZHI TECHNOLOGIES
#  95 of 233 - MENMOZHI TECHNOLOGIES -- Unknown Location
# ... Failed to get a location for COMMUNITY FOUNDATION FOR CHILDREN AND AGING
#  96 of 233 - COMMUNITY FOUNDATION FOR CHILDREN AND AGING -- Unknown Location
# ... Failed to get a location for Infosys
#  97 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Deloitte
#  98 of 233 - Deloitte -- Unknown Location
# ... Failed to get a location for Infosys
#  99 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 100 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Ganit Inc.
# 101 of 233 - Ganit Inc. -- Unknown Location
# ... Failed to get a location for Infosys
# 102 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 103 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Impetus
# 104 of 233 - Impetus -- Unknown Location
# ... Failed to get a location for Bosch Global Software Technologies
# 105 of 233 - Bosch Global Software Technologies -- Unknown Location
# ... Failed to get a location for Quantiphi
# 106 of 233 - Quantiphi -- Unknown Location
# ... Failed to get a location for Infosys
# 107 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for
# 108 of 233 -  -- Unknown Location
# ... Failed to get a location for
# 109 of 233 -  -- Unknown Location
# ... Failed to get a location for IBM India Private Limited
# 110 of 233 - IBM India Private Limited -- Unknown Location
# ... Failed to get a location for Infosys
# 111 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Zoho Corporation
# 112 of 233 - Zoho Corporation -- Unknown Location
# ... Failed to get a location for Infosys
# 113 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 114 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Tata Consultancy Services
# 115 of 233 - Tata Consultancy Services -- Unknown Location
# ... Failed to get a location for Infosys
# 116 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 117 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 118 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for IN-D - Power of AI
# 119 of 233 - IN-D - Power of AI -- Unknown Location
# ... Failed to get a location for Infosys
# 120 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Vuram
# 121 of 233 - Vuram -- Unknown Location
# ... Failed to get a location for SkyPoint Cloud
# 122 of 233 - SkyPoint Cloud -- Unknown Location
# ... Failed to get a location for Infosys
# 123 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Mu Sigma Inc.
# 124 of 233 - Mu Sigma Inc. -- Unknown Location
# ... Failed to get a location for Reliance Jio
# 125 of 233 - Reliance Jio -- Unknown Location
# ... Failed to get a location for Infosys
# 126 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 127 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Wipro
# 128 of 233 - Wipro -- Unknown Location
# ... Failed to get a location for Infosys
# 129 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 130 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Microsoft
# 131 of 233 - Microsoft -- Unknown Location
# ... Failed to get a location for Infosys
# 132 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Wipro Limited
# 133 of 233 - Wipro Limited -- Unknown Location
# ... Failed to get a location for Infosys
# 134 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for KPMG Global Services (KGS)
# 135 of 233 - KPMG Global Services (KGS) -- Unknown Location
# ... Failed to get a location for PowerSchool
# 136 of 233 - PowerSchool -- Unknown Location
# ... Failed to get a location for TELUS International
# 137 of 233 - TELUS International -- Unknown Location
# ... Failed to get a location for Accenture
# 138 of 233 - Accenture -- Unknown Location
# ... Failed to get a location for Subex
# 139 of 233 - Subex -- Unknown Location
# ... Failed to get a location for Infosys
# 140 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for
# 141 of 233 -  -- Unknown Location
# ... Failed to get a location for Infosys
# 142 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 143 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 144 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys Ltd
# 145 of 233 - Infosys Ltd -- Unknown Location
# ... Failed to get a location for Infosys
# 146 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Cloudside Technologies
# 147 of 233 - Cloudside Technologies -- Unknown Location
# ... Failed to get a location for AT&T
# 148 of 233 - AT&T -- Unknown Location
# ... Failed to get a location for Infosys
# 149 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Accenture
# 150 of 233 - Accenture -- Unknown Location
# ... Failed to get a location for Infosys
# 151 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Wipro
# 152 of 233 - Wipro -- Unknown Location
# ... Failed to get a location for Infosys
# 153 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Capgemini Engineering
# 154 of 233 - Capgemini Engineering -- Unknown Location
# ... Failed to get a location for Infosys
# 155 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Deloitte
# 156 of 233 - Deloitte -- Unknown Location
# ... Failed to get a location for Infosys
# 157 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 158 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 159 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 160 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 161 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 162 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 163 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 164 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 165 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 166 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 167 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 168 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 169 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 170 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 171 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys Limited
# 172 of 233 - Infosys Limited -- Unknown Location
# ... Failed to get a location for
# 173 of 233 -  -- Unknown Location
# ... Failed to get a location for
# 174 of 233 -  -- Unknown Location
# ... Failed to get a location for Wipro
# 175 of 233 - Wipro -- Unknown Location
# ... Failed to get a location for
# 176 of 233 -  -- Unknown Location
# ... Failed to get a location for MENMOZHI TECHNOLOGIES
# 177 of 233 - MENMOZHI TECHNOLOGIES -- Unknown Location
# ... Failed to get a location for Vagus Technologies
# 178 of 233 - Vagus Technologies -- Unknown Location
# ... Failed to get a location for Aelum Consulting - ServiceNow Premier Partner
# 179 of 233 - Aelum Consulting - ServiceNow Premier Partner -- Unknown Location
# ... Failed to get a location for
# 180 of 233 -  -- Unknown Location
# ... Failed to get a location for
# 181 of 233 -  -- Unknown Location
# ... Failed to get a location for
# 182 of 233 -  -- Unknown Location
# ... Failed to get a location for INNODATATICS * Innovation | Data | Analytics
# 183 of 233 - INNODATATICS * Innovation | Data | Analytics -- Unknown Location
# ... Failed to get a location for Bishop Heber College, Tiruchirappalli - 620 017.
# 184 of 233 - Bishop Heber College, Tiruchirappalli - 620 017. -- Unknown Location
# ... Failed to get a location for Learn and Build
# 185 of 233 - Learn and Build -- Unknown Location
# ... Failed to get a location for
# 186 of 233 -  -- Unknown Location
# ... Failed to get a location for Altametrics
# 187 of 233 - Altametrics -- Unknown Location
# ... Failed to get a location for
# 188 of 233 -  -- Unknown Location
# ... Failed to get a location for Tiger Analytics
# 189 of 233 - Tiger Analytics -- Unknown Location
# ... Failed to get a location for The Sparks Foundation
# 190 of 233 - The Sparks Foundation -- Unknown Location
# ... Failed to get a location for Infosys
# 191 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for
# 192 of 233 -  -- Unknown Location
# ... Failed to get a location for LetsGrowMore
# 193 of 233 - LetsGrowMore -- Unknown Location
# ... Failed to get a location for AstraZeneca
# 194 of 233 - AstraZeneca -- Unknown Location
# ... Failed to get a location for
# 195 of 233 -  -- Unknown Location
# ... Failed to get a location for Infosys
# 196 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 197 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for adarsh knitwear pvt ltd
# 198 of 233 - adarsh knitwear pvt ltd -- Unknown Location
# ... Failed to get a location for Infosys
# 199 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 200 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Bishop Heber College, Tiruchirappalli - 620 017.
# 201 of 233 - Bishop Heber College, Tiruchirappalli - 620 017. -- Unknown Location
# ... Failed to get a location for Kissflow
# 202 of 233 - Kissflow -- Unknown Location
# ... Failed to get a location for Bishop Heber College, Tiruchirappalli - 620 017.
# 203 of 233 - Bishop Heber College, Tiruchirappalli - 620 017. -- Unknown Location
# ... Failed to get a location for Areteans
# 204 of 233 - Areteans -- Unknown Location
# ... Failed to get a location for Mila - Quebec Artificial Intelligence Institute
# 205 of 233 - Mila - Quebec Artificial Intelligence Institute -- Unknown Location
# ... Failed to get a location for Infosys
# 206 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 207 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Accenture
# 208 of 233 - Accenture -- Unknown Location
# ... Failed to get a location for Infosys
# 209 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys Ltd
# 210 of 233 - Infosys Ltd -- Unknown Location
# ... Failed to get a location for IBM
# 211 of 233 - IBM -- Unknown Location
# ... Failed to get a location for Morningstar
# 212 of 233 - Morningstar -- Unknown Location
# ... Failed to get a location for Infosys
# 213 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 214 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Network Intelligence
# 215 of 233 - Network Intelligence  -- Unknown Location
# ... Failed to get a location for Infosys
# 216 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 217 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for
# 218 of 233 -  -- Unknown Location
# ... Failed to get a location for Coal India Limited
# 219 of 233 - Coal India Limited -- Unknown Location
# ... Failed to get a location for Infosys
# 220 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 221 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Infosys
# 222 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for UKG
# 223 of 233 - UKG -- Unknown Location
# ... Failed to get a location for Infosys
# 224 of 233 - Infosys -- Unknown Location
# ... Failed to get a location for Cognizant
# 225 of 233 - Cognizant -- Unknown Location
# ... Failed to get a location for Poshmark
# 226 of 233 - Poshmark -- Unknown Location
# ... Failed to get a location for
# 227 of 233 -  -- Unknown Location
# ... Failed to get a location for
# 228 of 233 -  -- Unknown Location
# ... Failed to get a location for Bali Dyslexia Foundation
# 229 of 233 - Bali Dyslexia Foundation  -- Unknown Location
# ... Failed to get a location for Medtronic
# 230 of 233 - Medtronic -- Unknown Location
# ... Failed to get a location for BYJU'S
# 231 of 233 - BYJU'S -- Unknown Location
# ... Failed to get a location for
# 232 of 233 -  -- Unknown Location
# ... Failed to get a location for Guardian Life
# 233 of 233 - Guardian Life -- Unknown Location

# %% [markdown]
# #**Clustering job titles using a greedy heuristic**

# %%
from nltk.util import bigrams

ceo_bigrams = list(bigrams("Chief Executive Officer".split(), pad_left=True, pad_right=True))
cto_bigrams = list(bigrams("Chief Technology Officer".split(), pad_left=True, pad_right=True))

print(ceo_bigrams)
print(cto_bigrams)

print(len(set(ceo_bigrams).intersection(set(cto_bigrams))))
# Out:
# [(None, 'Chief'), ('Chief', 'Executive'), ('Executive', 'Officer'), ('Officer', None)]
# [(None, 'Chief'), ('Chief', 'Technology'), ('Technology', 'Officer'), ('Officer', None)]
# 2

# %% [markdown]
# ###Jaccard distance calculation

# %%
from nltk.metrics.distance import jaccard_distance # pip install nltk

job_title_1 = 'Chief Executive Officer'.split()
job_title_2 = 'Chief Technology Officer'.split()

print(job_title_1)
print(job_title_2)

print()
print('Intersection:')
intersection = set(job_title_1).intersection(set(job_title_2))
print(intersection)

print()
print('Union:')
union = set(job_title_1).union(set(job_title_2))
print(union)

print()
print('Similarity:', len(intersection) / len(union))
print('Distance:', jaccard_distance(set(job_title_1), set(job_title_2)))
# Out:
# ['Chief', 'Executive', 'Officer']
# ['Chief', 'Technology', 'Officer']
#
# Intersection:
# {'Officer', 'Chief'}
#
# Union:
# {'Executive', 'Chief', 'Technology', 'Officer'}
#
# Similarity: 0.5
# Distance: 0.5

# %%
job_title_1 = 'Vice President, Sales'.split()
job_title_2 = 'Vice President, Customer Relations'.split()

print(job_title_1)
print(job_title_2)

print()
print('Intersection:')
intersection = set(job_title_1).intersection(set(job_title_2))
print(intersection)

print()
print('Union:')
union = set(job_title_1).union(set(job_title_2))
print(union)

print()
print('Similarity:', len(intersection) / len(union))
print('Distance:', jaccard_distance(set(job_title_1), set(job_title_2)))
# Out:
# ['Vice', 'President,', 'Sales']
# ['Vice', 'President,', 'Customer', 'Relations']
#
# Intersection:
# {'Vice', 'President,'}
#
# Union:
# {'Sales', 'Relations', 'President,', 'Vice', 'Customer'}
#
# Similarity: 0.4
# Distance: 0.6

# %%
contacts
# Out:
# [OrderedDict([('First Name', 'Sathish'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Navabrind IT Solutions Pvt Ltd'),
#               ('Position', 'Software Developer'),
#               ('Connected On', '07-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Padmanaban '),
#               ('Last Name', 'T  Yadava'),
#               ('Email Address', 'ctr.padmanaban@gmail.com'),
#               ('Company', 'Jio ( Veremax Technologies)'),
#               ('Position', 'Executive'),
#               ('Connected On', '07-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rahul'),
#               ('Last Name', 'Venkat S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '06-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Austin'),
#               ('Last Name', 'Chou'),
#               ('Email Address', ''),
#               ('Company', 'DataRobot'),
#               ('Position', 'Customer Facing Data Scientist'),
#               ('Connected On', '04-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jonathan'),
#               ('Last Name', 'Barda'),
#               ('Email Address', ''),
#               ('Company', 'Databand.ai'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '04-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Natheem'),
#               ('Last Name', 'H'),
#               ('Email Address', ''),
#               ('Company', 'Barclays'),
#               ('Position', 'Process Advisor - HR Operations'),
#               ('Connected On', '01-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'AYUSH'),
#               ('Last Name', 'GUPTA'),
#               ('Email Address', ''),
#               ('Company', 'NOBORDER.z'),
#               ('Position', 'Artificial Intelligence Engineer'),
#               ('Connected On', '29-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Andrew Weida'),
#               ('Last Name', 'Liew'),
#               ('Email Address', ''),
#               ('Company', 'Qicstart'),
#               ('Position', 'Data Science Partner'),
#               ('Connected On', '27-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Indumathi'),
#               ('Last Name', 'Palanikumar'),
#               ('Email Address', ''),
#               ('Company', 'Indian Institute of Technology, Madras'),
#               ('Position', 'Research Scholar'),
#               ('Connected On', '25-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'sowmya'),
#               ('Last Name', 'srinivasan'),
#               ('Email Address', ''),
#               ('Company', 'Azzure'),
#               ('Position', 'Digital Marketing Specialist'),
#               ('Connected On', '25-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mihika'),
#               ('Last Name', 'Likhite'),
#               ('Email Address', ''),
#               ('Company', 'Crompton Greaves Consumer Electricals Limited'),
#               ('Position', 'Data Analytics Intern '),
#               ('Connected On', '23-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. Selva Rani'),
#               ('Last Name', 'B'),
#               ('Email Address', ''),
#               ('Company', 'Vellore Institute of Technology'),
#               ('Position', 'Associate Professor'),
#               ('Connected On', '22-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Riyaz'),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Self-employed'),
#               ('Position', 'Business Owner'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ritam'),
#               ('Last Name', 'Bandyopadhyay'),
#               ('Email Address', ''),
#               ('Company', 'Spinny'),
#               ('Position', 'SDE-1'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Godly'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Programmer Analyst'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sameer'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Bank of America'),
#               ('Position', 'Academic Technical Intern'),
#               ('Connected On', '11-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SHIV RAM'),
#               ('Last Name', 'SINGH'),
#               ('Email Address', ''),
#               ('Company', 'Coforge'),
#               ('Position', 'Senior Software Engineer'),
#               ('Connected On', '09-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ritesh'),
#               ('Last Name', 'Arora'),
#               ('Email Address', ''),
#               ('Company', 'Apple'),
#               ('Position',
#                'Director - Data Analytics and Artificial Intelligence'),
#               ('Connected On', '05-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operation Executive'),
#               ('Connected On', '05-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'karthikeyan'),
#               ('Last Name', 'ponmudi'),
#               ('Email Address', ''),
#               ('Company', 'Stealth Mode Startup Company'),
#               ('Position', 'Founder'),
#               ('Connected On', '04-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vikram'),
#               ('Last Name', 'Kamboj'),
#               ('Email Address', ''),
#               ('Company', 'Microsoft'),
#               ('Position', 'Senior Data Scientist'),
#               ('Connected On', '20-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rishi M'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Altus Health Care Solutions'),
#               ('Position', 'Marketing and Operations Manager'),
#               ('Connected On', '18-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anil'),
#               ('Last Name', 'Reddy'),
#               ('Email Address', ''),
#               ('Company', 'Rkinformatics pvt ltd'),
#               ('Position', 'It recruiter'),
#               ('Connected On', '15-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Selvakumar'),
#               ('Last Name', 'Gnanavel'),
#               ('Email Address', ''),
#               ('Company', 'Muthayammal College of Arts & Science'),
#               ('Position', 'Assistant Professor of Computer Science'),
#               ('Connected On', '15-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Tava'),
#               ('Last Name', 'Manggai'),
#               ('Email Address', ''),
#               ('Company',
#                'Malaysian Communications and Multimedia Commission'),
#               ('Position', 'Head, Talent Management'),
#               ('Connected On', '13-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. F.A.K'),
#               ('Last Name', '(Noble)'),
#               ('Email Address', ''),
#               ('Company', 'Noble Transformation Hub (Ai)'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '12-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Roshini'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Aram Visas'),
#               ('Position', 'Senior Immigration Consultant'),
#               ('Connected On', '10-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vetrichelvan'),
#               ('Last Name', 'Dhanasekaran'),
#               ('Email Address', ''),
#               ('Company', 'Indian Institute of Technology, Madras'),
#               ('Position', 'Masters Student'),
#               ('Connected On', '08-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'C R'),
#               ('Last Name', 'LAKSHMI'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Wasim'),
#               ('Last Name', 'Fyrose'),
#               ('Email Address', ''),
#               ('Company', 'Walmart Global Tech India'),
#               ('Position', 'Software Engineer III'),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jay'),
#               ('Last Name', 'Charole'),
#               ('Email Address', ''),
#               ('Company', 'Zep Analytics'),
#               ('Position', 'Data Analyst and Business Developer'),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Venkatesh'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Zoho'),
#               ('Position', 'Member Technical Staff'),
#               ('Connected On', '05-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rakesh'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst(iOS)'),
#               ('Connected On', '03-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'vinoth'),
#               ('Last Name', 'kumar'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Training Analyst'),
#               ('Connected On', '01-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Haneef'),
#               ('Last Name', 'Shaik'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '31-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Atul'),
#               ('Last Name', 'Batra'),
#               ('Email Address', ''),
#               ('Company', 'Algonomy'),
#               ('Position', 'CTO'),
#               ('Connected On', '25-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yiqun'),
#               ('Last Name', 'Hu'),
#               ('Email Address', ''),
#               ('Company', 'NTUC Enterprise Co-operative Limited'),
#               ('Position', 'Chief Data Officer'),
#               ('Connected On', '25-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abishek'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'HSBC'),
#               ('Position', 'Data Scientist - FinOps'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Chris'),
#               ('Last Name', 'Hopkins'),
#               ('Email Address', ''),
#               ('Company', 'Evolution Recruitment Solutions, USA'),
#               ('Position', 'Vice President USA'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Madhav'),
#               ('Last Name', 'Didolkar'),
#               ('Email Address', ''),
#               ('Company', 'Shyena Tech Yarns Pvt Ltd'),
#               ('Position', 'Director - Business Development'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Santhosh Sivan'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Data Science Research Scholar'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Archna'),
#               ('Last Name', 'Wadhwa'),
#               ('Email Address', ''),
#               ('Company', 'Analytics Saves at Work'),
#               ('Position', 'Founder and CEO'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sharala'),
#               ('Last Name', 'Axryd'),
#               ('Email Address', ''),
#               ('Company', 'The Center of Applied Data Science'),
#               ('Position', 'Founder and Chief Executive Officer'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sunil'),
#               ('Last Name', 'David'),
#               ('Email Address', ''),
#               ('Company', 'TagBox'),
#               ('Position', 'Advisor'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mario'),
#               ('Last Name', 'Cartia'),
#               ('Email Address', ''),
#               ('Company', 'Freelance'),
#               ('Position', 'Consultant & Technology Evangelist'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prem'),
#               ('Last Name', 'Rishi R'),
#               ('Email Address', ''),
#               ('Company', 'LTI - Larsen & Toubro Infotech'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jason Tamara'),
#               ('Last Name', 'Widjaja'),
#               ('Email Address', ''),
#               ('Company', 'MSD'),
#               ('Position', 'Director of Artificial Intelligence'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prabhjot'),
#               ('Last Name', 'Singh Aman'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'ServiceNow Developer'),
#               ('Connected On', '23-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Manoj Kumar'),
#               ('Last Name', 'Patel'),
#               ('Email Address', ''),
#               ('Company', 'HSIN'),
#               ('Position', 'Manager - Technology Services '),
#               ('Connected On', '20-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Suhas'),
#               ('Last Name', 'Kudekar'),
#               ('Email Address', ''),
#               ('Company', 'Synechron'),
#               ('Position', 'Specialist - Technology'),
#               ('Connected On', '11-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Joel'),
#               ('Last Name', 'Andrews Jeyakumar'),
#               ('Email Address', ''),
#               ('Company', 'CGI'),
#               ('Position', 'Associate Software Engineer'),
#               ('Connected On', '11-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayachandran'),
#               ('Last Name', 'J'),
#               ('Email Address', ''),
#               ('Company', 'Tata Consultancy Services'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '09-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayasurya'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'Actify Data Labs'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '23-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abinesh Siva'),
#               ('Last Name', 'Manikandan J R'),
#               ('Email Address', ''),
#               ('Company', 'IELEKTRON TECHNOLOGIES PVT. LTD.'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '13-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mohit'),
#               ('Last Name', 'Bhat'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Analyst'),
#               ('Connected On', '13-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. X .Agnello'),
#               ('Last Name', 'J Naveen'),
#               ('Email Address', ''),
#               ('Company',
#                'THANTHAI ROEVER INSTITUTE OF AGRICULTURE AND RURAL DEVELOPMENT, PERAMBALUR'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '12-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'siya'),
#               ('Last Name', 'ram'),
#               ('Email Address', ''),
#               ('Company', 'Self-Employed'),
#               ('Position', 'Information Technology'),
#               ('Connected On', '04-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'k'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '04-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ragupathi'),
#               ('Last Name', 'Thangavel'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '17-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sujith'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '16-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dazil'),
#               ('Last Name', 'Fernandez'),
#               ('Email Address', ''),
#               ('Company', 'Success Enablers India'),
#               ('Position', 'Founder and Principal Consultant'),
#               ('Connected On', '15-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sampathkumar'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '09-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'E'),
#               ('Last Name', 'Sundar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mani kandan'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', 'DXC Technology'),
#               ('Position', 'Associate professional application developer'),
#               ('Connected On', '22-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Manikandan'),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Vestige Marketing Pvt. Ltd.'),
#               ('Position', 'Entrepreneur'),
#               ('Connected On', '16-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nambirajan'),
#               ('Last Name', 'R S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '15-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'DHANAPRIYA'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '15-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Naman'),
#               ('Last Name', 'Tripathi'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '10-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ashwini'),
#               ('Last Name', 'Jha'),
#               ('Email Address', ''),
#               ('Company', 'UBS'),
#               ('Position', 'Associate Director - Data Science'),
#               ('Connected On', '06-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Stanley'),
#               ('Last Name', 'Kapil dev'),
#               ('Email Address', ''),
#               ('Company', 'Paytm'),
#               ('Position', 'Area Sales Manager'),
#               ('Connected On', '31-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Om'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nivetha'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '27-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Thiru'),
#               ('Last Name', 'Varangan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Harsha'),
#               ('Last Name', 'vardhan'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Scholar Trainee'),
#               ('Connected On', '22-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rexson'),
#               ('Last Name', 'Epiron'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '21-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Suyash'),
#               ('Last Name', 'Rastogi'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Consultant'),
#               ('Connected On', '20-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ruthsan'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'OptiSol Business Solutions'),
#               ('Position', 'Full Stack Developer'),
#               ('Connected On', '18-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vinod'),
#               ('Last Name', '.'),
#               ('Email Address', ''),
#               ('Company', "BYJU'S"),
#               ('Position', 'Operation executive'),
#               ('Connected On', '15-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MUHIL'),
#               ('Last Name', 'ARASAN'),
#               ('Email Address', ''),
#               ('Company', 'Merkle'),
#               ('Position', 'Associate Analyst'),
#               ('Connected On', '15-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Dalal'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '12-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'RITESH'),
#               ('Last Name', 'DANGADE'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science & Business Analytics'),
#               ('Connected On', '07-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vaibhav'),
#               ('Last Name', 'Oza'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst'),
#               ('Connected On', '07-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Saurabh'),
#               ('Last Name', 'Anand'),
#               ('Email Address', ''),
#               ('Company', 'Wipro Technologies '),
#               ('Position', 'Senior Software Developer'),
#               ('Connected On', '30-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Utkarsh'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '27-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Christopher Immanuel'),
#               ('Last Name', 'Prince P J'),
#               ('Email Address', ''),
#               ('Company', 'EXL Health'),
#               ('Position', 'Data Analyst Intern'),
#               ('Connected On', '24-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Madhumitha'),
#               ('Last Name', 'Marsaleen'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte Consulting'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '18-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Gayathri'),
#               ('Last Name', 'Sakthivel'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '18-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'CLINTAN '),
#               ('Last Name', 'CYRIL A'),
#               ('Email Address', ''),
#               ('Company', 'Worksbot Applications Private Limited'),
#               ('Position', 'Machine Learning Engineer'),
#               ('Connected On', '17-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SUDHARSHINI'),
#               ('Last Name', 'B'),
#               ('Email Address', ''),
#               ('Company', 'REGex Software Services'),
#               ('Position', 'MEARN SUMMER INTERN'),
#               ('Connected On', '13-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sanant'),
#               ('Last Name', 'Sampathkumar'),
#               ('Email Address', ''),
#               ('Company', 'Vista'),
#               ('Position', 'Data Product Manager'),
#               ('Connected On', '12-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dhivyadharshni'),
#               ('Last Name', 'Natarajan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '12-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'karthik'),
#               ('Last Name', 's'),
#               ('Email Address', ''),
#               ('Company', 'Zoho Corporation'),
#               ('Position', 'Member Of Technical Staff'),
#               ('Connected On', '09-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rajesh'),
#               ('Last Name', 'Kannan M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Harish'),
#               ('Last Name', 'Dornal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Hariharasudhan'),
#               ('Last Name', 'D'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Intern'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aneesa'),
#               ('Last Name', 'Sumaira'),
#               ('Email Address', ''),
#               ('Company', 'COMMUNITY FOUNDATION FOR CHILDREN AND AGING'),
#               ('Position', 'Communication - Human Resource Executive'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhiraj'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '04-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Danish'),
#               ('Last Name', 'Ahmed Jaffery'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Learning & Development Specialist'),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shobhit'),
#               ('Last Name', 'Srivastava'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sreerag'),
#               ('Last Name', 'M Surendran'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Operation Executive '),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ram'),
#               ('Last Name', 'Kishore'),
#               ('Email Address', ''),
#               ('Company', 'Ganit Inc.'),
#               ('Position', 'Data Analyst - Intern'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anuj'),
#               ('Last Name', 'Jain'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abishekraj'),
#               ('Last Name', 'Vinayagar Gnanasambandam'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'VIPIN'),
#               ('Last Name', 'SHUKLA'),
#               ('Email Address', ''),
#               ('Company', 'Impetus'),
#               ('Position', 'Senior Software Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Varshini'),
#               ('Last Name', 'Kuppusami '),
#               ('Email Address', ''),
#               ('Company', 'Bosch Global Software Technologies'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '01-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Samit'),
#               ('Last Name', 'Saxena'),
#               ('Email Address', ''),
#               ('Company', 'Quantiphi'),
#               ('Position', 'Senior Machine Learning Engineer'),
#               ('Connected On', '01-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'HARI'),
#               ('Last Name', 'UNNIKRISHNAN'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'VIMAL'),
#               ('Last Name', 'S E'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bharat'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dinesh'),
#               ('Last Name', 'Shivakumar'),
#               ('Email Address', ''),
#               ('Company', 'IBM India Private Limited'),
#               ('Position', 'Service Support Manager'),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Navjot'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '29-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prabhu'),
#               ('Last Name', 'Sarathy'),
#               ('Email Address', ''),
#               ('Company', 'Zoho Corporation'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '29-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Marivignesh '),
#               ('Last Name', 'N'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Engineer'),
#               ('Connected On', '28-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anand'),
#               ('Last Name', 'Nagar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '28-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MD SHARIQUE'),
#               ('Last Name', 'BEG'),
#               ('Email Address', ''),
#               ('Company', 'Tata Consultancy Services'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '27-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yawar'),
#               ('Last Name', 'Siddiqui'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '27-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shalvi'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kamalakannan'),
#               ('Last Name', 'T'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sri'),
#               ('Last Name', 'Hari'),
#               ('Email Address', ''),
#               ('Company', 'IN-D - Power of AI'),
#               ('Position', 'R and D engineer trainee'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shaji'),
#               ('Last Name', 'Mathew'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Executive Vice President'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Hari'),
#               ('Last Name', 'Bhagirath'),
#               ('Email Address', ''),
#               ('Company', 'Vuram'),
#               ('Position', 'Corporate Communications'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arun'),
#               ('Last Name', 'Raja'),
#               ('Email Address', ''),
#               ('Company', 'SkyPoint Cloud'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Devang'),
#               ('Last Name', 'Mathur'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Muthu Periyaval'),
#               ('Last Name', 'G S'),
#               ('Email Address', ''),
#               ('Company', 'Mu Sigma Inc.'),
#               ('Position', 'Decision Scientist '),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Preethi'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', 'Reliance Jio'),
#               ('Position', 'Manager - IT IRM & Cyber Security EPS&F'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Adarsh'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Divyanshu'),
#               ('Last Name', 'Kuksal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sumit Shankar'),
#               ('Last Name', 'Das'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Technical Lead - Oracle Integration Practice'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shambhavi'),
#               ('Last Name', 'Shruti'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sai Aishwarya'),
#               ('Last Name', 'Vernekar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Anand'),
#               ('Email Address', ''),
#               ('Company', 'Microsoft'),
#               ('Position', 'Software Engineer II (Azure Redis Cache)'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Priyansh'),
#               ('Last Name', 'Acharya'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Enayat Haider (PRINCE2,Cybersecurity,'),
#               ('Last Name', 'AWS-Cloud,ITIL,CCNP,B.Tech,MBA-IT)'),
#               ('Email Address', ''),
#               ('Company', 'Wipro Limited'),
#               ('Position', 'Infrastructure Project Manager'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aditi'),
#               ('Last Name', 'Agrawal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sai Ramcharan'),
#               ('Last Name', 'Tangirala'),
#               ('Email Address', ''),
#               ('Company', 'KPMG Global Services (KGS)'),
#               ('Position', 'Associate Consultant'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rushabh'),
#               ('Last Name', 'Shah'),
#               ('Email Address', ''),
#               ('Company', 'PowerSchool'),
#               ('Position', 'Software Engineer II'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhimanyu'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'TELUS International'),
#               ('Position', 'Senior Applications Developer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Apoorva'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Strategy Analyst | India Market Unit'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shabutheen'),
#               ('Last Name', 'Basha'),
#               ('Email Address', 'shabutheenbasha@outlook.com'),
#               ('Company', 'Subex'),
#               ('Position', 'Data Analyst - Lead'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Divya Harish'),
#               ('Last Name', 'Kodandera'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Principal Consultant - Learning'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mohan'),
#               ('Last Name', 'Ramachandran'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhupinder Singh'),
#               ('Last Name', 'Chawla'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Group Project Manager'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nishchal'),
#               ('Last Name', 'Sharan'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'DevOps Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Monika'),
#               ('Last Name', 'Ashok Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys Ltd'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yash'),
#               ('Last Name', 'Narang'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Praveenraaj'),
#               ('Last Name', 'Shanmugam'),
#               ('Email Address', ''),
#               ('Company', 'Cloudside Technologies'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Karthick'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'AT&T'),
#               ('Position', 'Senior Associate'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhinandan'),
#               ('Last Name', 'Jain'),
#               ('Email Address', 'abhinandan170398@gmail.com'),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer/Business Analyst '),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Muthu'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Application Development Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sanjeeda'),
#               ('Last Name', 'Yasmeen'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ragavan'),
#               ('Last Name', 'S T'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Senior Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kavin'),
#               ('Last Name', 'Saravanan'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shrihari'),
#               ('Last Name', 'Ravichandran'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini Engineering'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Swati'),
#               ('Last Name', 'Talwar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Associate Consultant'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'ATUL'),
#               ('Last Name', 'AKASH'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prasanth'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhumi'),
#               ('Last Name', 'Tiwari'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Associate Lead HR- Employee Relations'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Ronkhede'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer - Data Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Cibisasidharan'),
#               ('Last Name', 'ShanmugaSundaram'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhayyasaheb'),
#               ('Last Name', 'Gaikwad'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Badri Narayanan'),
#               ('Last Name', 'C V'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SUBHAJIT'),
#               ('Last Name', 'SINHA'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Venkataraman'),
#               ('Email Address', ''),
# ...
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Azmal'),
#               ('Last Name', 'Ahamed'),
#               ('Email Address', ''),
#               ('Company', 'Aelum Consulting - ServiceNow Premier Partner'),
#               ('Position', 'Business Analyst'),
#               ('Connected On', '10-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MUTHULASKMI'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Daya Anandhi'),
#               ('Last Name', 'Jayaraman'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jo-Anna'),
#               ('Last Name', 'Elizabeth J'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Varun'),
#               ('Last Name', 'Reddy'),
#               ('Email Address', ''),
#               ('Company', 'INNODATATICS * Innovation | Data | Analytics'),
#               ('Position',
#                'Manager- Analytics & Business Development (India)'),
#               ('Connected On', '06-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SHARON'),
#               ('Last Name', 'SAM S'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Student'),
#               ('Connected On', '02-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yokeshwaran '),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', 'Learn and Build'),
#               ('Position', 'Summer Intern'),
#               ('Connected On', '02-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Saravanan'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '24-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sagar'),
#               ('Last Name', 'Sharma'),
#               ('Email Address', ''),
#               ('Company', 'Altametrics'),
#               ('Position', 'Datacenter Administrator'),
#               ('Connected On', '14-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'ranjani'),
#               ('Last Name', 'balasubramanian'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '13-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Gyan Prakash '),
#               ('Last Name', 'Konhar'),
#               ('Email Address', ''),
#               ('Company', 'Tiger Analytics'),
#               ('Position', 'Data Science - Analyst'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vissweswaran'),
#               ('Last Name', 'C'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science and Business Analystics Intern'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SATHEES'),
#               ('Last Name', 'KUMAR'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Analyst'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sujitha'),
#               ('Last Name', 'Rajasekaran'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '02-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sachin'),
#               ('Last Name', 'Isravel V'),
#               ('Email Address', ''),
#               ('Company', 'LetsGrowMore'),
#               ('Position', 'Data Science Intern'),
#               ('Connected On', '29-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SASIDHARAN'),
#               ('Last Name', 'C '),
#               ('Email Address', ''),
#               ('Company', 'AstraZeneca'),
#               ('Position', 'Engineer'),
#               ('Connected On', '29-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '27-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Amit'),
#               ('Last Name', 'Vanjode'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '27-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sumit'),
#               ('Last Name', 'Bhomia'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '23-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ramya'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', 'adarsh knitwear pvt ltd'),
#               ('Position', 'Management Intern'),
#               ('Connected On', '22-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arnab'),
#               ('Last Name', 'Goswami'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '18-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aniket'),
#               ('Last Name', 'Chatterjee'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Systems Engineer'),
#               ('Connected On', '18-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jemimah'),
#               ('Last Name', 'Kandaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Eugene'),
#               ('Last Name', 'Kingsley'),
#               ('Email Address', ''),
#               ('Company', 'Kissflow'),
#               ('Position', 'Technical Solution Specialist'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'Selvaraj PhD'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shivani'),
#               ('Last Name', 'Sharma'),
#               ('Email Address', ''),
#               ('Company', 'Areteans'),
#               ('Position', 'Senior Consultant QA'),
#               ('Connected On', '05-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arjun'),
#               ('Last Name', 'V S'),
#               ('Email Address', ''),
#               ('Company', 'Mila - Quebec Artificial Intelligence Institute'),
#               ('Position', 'Student Researcher'),
#               ('Connected On', '03-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shweta'),
#               ('Last Name', 'Hooda'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Software Developer'),
#               ('Connected On', '28-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'simran'),
#               ('Last Name', 'sahu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '28-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aashi'),
#               ('Last Name', 'Jain'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Application Development Analyst'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pratiksha'),
#               ('Last Name', 'Govindwar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vanishree'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys Ltd'),
#               ('Position', 'Learning & Development Associate'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aishwariya'),
#               ('Last Name', 'Vijaya kumar'),
#               ('Email Address', ''),
#               ('Company', 'IBM'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '26-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Deepak'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', 'Morningstar'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '26-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vivek'),
#               ('Last Name', 'Krishna'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '13-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Surya'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '10-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Nair'),
#               ('Email Address', ''),
#               ('Company', 'Network Intelligence '),
#               ('Position', 'Senior Cybersecurity Analyst'),
#               ('Connected On', '10-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pravalika'),
#               ('Last Name', 'Salina'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kaviyabharathi '),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prashant'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Coal India Limited'),
#               ('Position', 'Management Trainee'),
#               ('Connected On', '15-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Basila Fathima'),
#               ('Last Name', 'Babu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '10-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aparna '),
#               ('Last Name', 'Pappu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Associate Learning and Development '),
#               ('Connected On', '08-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Amoda'),
#               ('Last Name', 'S N'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhavna'),
#               ('Last Name', 'Bhardwaj'),
#               ('Email Address', ''),
#               ('Company', 'UKG'),
#               ('Position', 'Senior Talent Development Consultant'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shivani'),
#               ('Last Name', 'Selvaraj'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Programmer'),
#               ('Connected On', '31-May-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jaisurya'),
#               ('Last Name', 'Narayanan M'),
#               ('Email Address', ''),
#               ('Company', 'Poshmark'),
#               ('Position', 'Software Engineer I Web Applications'),
#               ('Connected On', '27-May-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Auxiliya'),
#               ('Last Name', 'C'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '14-Apr-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '01-Apr-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mark'),
#               ('Last Name', 'Stoddart'),
#               ('Email Address', ''),
#               ('Company', 'Bali Dyslexia Foundation '),
#               ('Position', 'Ambassador'),
#               ('Connected On', '29-Mar-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pavithran'),
#               ('Last Name', 'Murali'),
#               ('Email Address', ''),
#               ('Company', 'Medtronic'),
#               ('Position', 'Therapy Development Specialist- TAVR'),
#               ('Connected On', '28-Mar-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', "BYJU'S"),
#               ('Position', 'Academic Specialist'),
#               ('Connected On', '17-Nov-20'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Syed'),
#               ('Last Name', 'Ms'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '19-Jul-20'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayaprakash'),
#               ('Last Name', 'Ravichandran '),
#               ('Email Address', ''),
#               ('Company', 'Guardian Life'),
#               ('Position', 'Associate'),
#               ('Connected On', '06-Apr-20'),
#               ('Location', None)])]

# %%
import json
# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.6
DISTANCE = jaccard_distance



def cluster_contacts_by_title():

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', ' & ', '|', ',']

    # Normalize and/or replace known abbreviations
    # and build up a list of common titles.

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            try:
                distance = DISTANCE(set(title1.split()), set(title2.split()))
            except:
                print(title1.split())
                print(title2.split())
                continue

            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters
    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('{0} {1}.'.format(
                        contact['FirstName'], contact['LastName'][0]))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title()

for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    if len(descriptive_terms) == 0: descriptive_terms = ['***No words in common***']
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print(common_titles_heading)
    print('\n'+descriptive_terms_heading)
    print('-' * 70)
    print('\n'.join(clustered_contacts[titles]))
    print()
# Out:
# Common Titles: Customer Facing Data Scientist, Data Scientist
#
# Descriptive Terms: Data, Scientist
# ----------------------------------------------------------------------
#
#
# Common Titles: Student, Masters Student, Student Researcher
#
# Descriptive Terms: Student
# ----------------------------------------------------------------------
#
#
# Common Titles: Operation Executive, Senior Operation Executive , Executive
#
# Descriptive Terms: Executive
# ----------------------------------------------------------------------
#
#
# Common Titles: Digital Specialist Engineer, Digital Marketing Specialist
#
# Descriptive Terms: Digital, Specialist
# ----------------------------------------------------------------------
#
#
# Common Titles: Engineer, Systems Engineer, System Engineer, DevOps Engineer, Software Engineer, Test Engineer, Systems Engineer , Data Engineer
#
# Descriptive Terms: Engineer
# ----------------------------------------------------------------------
#
#
# Common Titles: Learning & Development Specialist, Learning & Development Associate
#
# Descriptive Terms: &, Learning, Development
# ----------------------------------------------------------------------
#
#
# Common Titles: Software Engineer II (Azure Redis Cache), Software Engineer II
#
# Descriptive Terms: Engineer, II, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Software Developer, Senior Software Developer
#
# Descriptive Terms: Developer, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Analyst, Data Analyst Intern, Data Science - Analyst, Analyst, Data Analyst - Lead, Data Analyst - Intern
#
# Descriptive Terms: Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Systems Engineer, Senior Systems Engineer, Systems Engineer
#
# Descriptive Terms: Engineer, Systems
# ----------------------------------------------------------------------
#
#
# Common Titles: System Engineer, System Engineer - Data Engineer, Senior System Engineer
#
# Descriptive Terms: Engineer, System
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Science Intern, Data Analytics Intern , Data Science Partner, Data Analyst Intern, Data Science and Business Analystics Intern
#
# Descriptive Terms: Data
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Cybersecurity Analyst, Senior Analyst
#
# Descriptive Terms: Senior, Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Associate Software Engineer, Software Engineer, Software Engineer III, Software Engineer II, Senior Software Engineer
#
# Descriptive Terms: Engineer, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Software Developer, Senior Applications Developer, Senior Software Engineer
#
# Descriptive Terms: Senior
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Consultant, Senior Consultant QA, Senior Talent Development Consultant, Senior Immigration Consultant
#
# Descriptive Terms: Consultant, Senior
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Data Scientist, Data Scientist
#
# Descriptive Terms: Data, Scientist
# ----------------------------------------------------------------------
#
#
# Common Titles: Software Engineer, Software Engineer III, Software Engineer II, Senior Software Engineer
#
# Descriptive Terms: Engineer, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Vice President USA, Executive Vice President
#
# Descriptive Terms: Vice, President
# ----------------------------------------------------------------------
#
#
# Common Titles: Business Analyst, Analyst
#
# Descriptive Terms: Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Analytics Intern , Data Analyst Intern
#
# Descriptive Terms: Intern, Data
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Scientist - FinOps, Data Scientist
#
# Descriptive Terms: Data, Scientist
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Consultant QA, Senior Immigration Consultant
#
# Descriptive Terms: Consultant, Senior
# ----------------------------------------------------------------------
#
#
# Common Titles: System Engineer - Data Engineer, Data Engineer
#
# Descriptive Terms: Engineer, Data
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Associate Learning and Development , Learning & Development Associate
#
# Descriptive Terms: Learning, Associate, Development
# ----------------------------------------------------------------------
#
#
# Common Titles: Technology Analyst, Analyst
#
# Descriptive Terms: Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Management Intern, Intern
#
# Descriptive Terms: Intern
# ----------------------------------------------------------------------
#
#
# Common Titles: Software Engineer III, Software Engineer II, Senior Software Engineer
#
# Descriptive Terms: Engineer, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Associate, Associate
#
# Descriptive Terms: Associate
# ----------------------------------------------------------------------
#
#
# Common Titles: Associate Director - Data Science, Data Science - Analyst
#
# Descriptive Terms: Data, -, Science
# ----------------------------------------------------------------------
#
#
# Common Titles: Member Technical Staff, Member Of Technical Staff
#
# Descriptive Terms: Staff, Technical, Member
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Analyst Intern, Data Analyst - Intern
#
# Descriptive Terms: Intern, Data, Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Summer Intern, Intern
#
# Descriptive Terms: Intern
# ----------------------------------------------------------------------
#
#
# Common Titles: Group Project Manager, Infrastructure Project Manager
#
# Descriptive Terms: Manager, Project
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Systems Engineer, Senior Software Engineer, Senior System Engineer, Systems Engineer
#
# Descriptive Terms: Engineer
# ----------------------------------------------------------------------
#
#
# Common Titles: Programmer, Programmer Analyst
#
# Descriptive Terms: Programmer
# ----------------------------------------------------------------------
#
#
# Common Titles: Machine Learning Engineer, Senior Machine Learning Engineer
#
# Descriptive Terms: Engineer, Learning, Machine
# ----------------------------------------------------------------------
#
#
# Common Titles: Software Engineer II, Senior Software Engineer
#
# Descriptive Terms: Engineer, Software
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Science - Analyst, Data Analyst - Lead, Data Analyst - Intern
#
# Descriptive Terms: Data, -, Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Associate, Associate Consultant, Associate Professor, Associate Analyst
#
# Descriptive Terms: Associate
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior System Engineer/Business Analyst , Senior Analyst
#
# Descriptive Terms: Senior, Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Operations Executive, Executive
#
# Descriptive Terms: Executive
# ----------------------------------------------------------------------
#
#
# Common Titles: Senior Software Engineer, Senior System Engineer
#
# Descriptive Terms: Engineer, Senior
# ----------------------------------------------------------------------
#
#
# Common Titles: Training Analyst, Analyst
#
# Descriptive Terms: Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Analyst, Senior Analyst, Programmer Analyst, Associate Analyst, Test Analyst
#
# Descriptive Terms: Analyst
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Science Research Scholar, Research Scholar
#
# Descriptive Terms: Scholar, Research
# ----------------------------------------------------------------------
#
#
# Common Titles: Data Analyst - Lead, Data Analyst - Intern
#
# Descriptive Terms: Data, -, Analyst
# ----------------------------------------------------------------------

# %% [markdown]
# ###How to export data to power a dendogram and node-link tree visualization

# %%
pip install cluster
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cluster in /usr/local/lib/python3.7/dist-packages (1.4.1.post3)

# %%
import cluster

# %%
contacts
# Out:
# [OrderedDict([('First Name', 'Sathish'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Navabrind IT Solutions Pvt Ltd'),
#               ('Position', ['Software Developer']),
#               ('Connected On', '07-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Padmanaban '),
#               ('Last Name', 'T  Yadava'),
#               ('Email Address', 'ctr.padmanaban@gmail.com'),
#               ('Company', 'Jio ( Veremax Technologies)'),
#               ('Position', ['Executive']),
#               ('Connected On', '07-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rahul'),
#               ('Last Name', 'Venkat S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '06-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Austin'),
#               ('Last Name', 'Chou'),
#               ('Email Address', ''),
#               ('Company', 'DataRobot'),
#               ('Position', 'Customer Facing Data Scientist'),
#               ('Connected On', '04-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jonathan'),
#               ('Last Name', 'Barda'),
#               ('Email Address', ''),
#               ('Company', 'Databand.ai'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '04-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Natheem'),
#               ('Last Name', 'H'),
#               ('Email Address', ''),
#               ('Company', 'Barclays'),
#               ('Position', 'Process Advisor - HR Operations'),
#               ('Connected On', '01-Aug-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'AYUSH'),
#               ('Last Name', 'GUPTA'),
#               ('Email Address', ''),
#               ('Company', 'NOBORDER.z'),
#               ('Position', 'Artificial Intelligence Engineer'),
#               ('Connected On', '29-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Andrew Weida'),
#               ('Last Name', 'Liew'),
#               ('Email Address', ''),
#               ('Company', 'Qicstart'),
#               ('Position', 'Data Science Partner'),
#               ('Connected On', '27-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Indumathi'),
#               ('Last Name', 'Palanikumar'),
#               ('Email Address', ''),
#               ('Company', 'Indian Institute of Technology, Madras'),
#               ('Position', 'Research Scholar'),
#               ('Connected On', '25-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'sowmya'),
#               ('Last Name', 'srinivasan'),
#               ('Email Address', ''),
#               ('Company', 'Azzure'),
#               ('Position', 'Digital Marketing Specialist'),
#               ('Connected On', '25-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mihika'),
#               ('Last Name', 'Likhite'),
#               ('Email Address', ''),
#               ('Company', 'Crompton Greaves Consumer Electricals Limited'),
#               ('Position', 'Data Analytics Intern '),
#               ('Connected On', '23-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. Selva Rani'),
#               ('Last Name', 'B'),
#               ('Email Address', ''),
#               ('Company', 'Vellore Institute of Technology'),
#               ('Position', 'Associate Professor'),
#               ('Connected On', '22-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Riyaz'),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Self-employed'),
#               ('Position', 'Business Owner'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ritam'),
#               ('Last Name', 'Bandyopadhyay'),
#               ('Email Address', ''),
#               ('Company', 'Spinny'),
#               ('Position', 'SDE-1'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Godly'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Programmer Analyst'),
#               ('Connected On', '15-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sameer'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Bank of America'),
#               ('Position', 'Academic Technical Intern'),
#               ('Connected On', '11-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SHIV RAM'),
#               ('Last Name', 'SINGH'),
#               ('Email Address', ''),
#               ('Company', 'Coforge'),
#               ('Position', 'Senior Software Engineer'),
#               ('Connected On', '09-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ritesh'),
#               ('Last Name', 'Arora'),
#               ('Email Address', ''),
#               ('Company', 'Apple'),
#               ('Position',
#                'Director - Data Analytics and Artificial Intelligence'),
#               ('Connected On', '05-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operation Executive'),
#               ('Connected On', '05-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'karthikeyan'),
#               ('Last Name', 'ponmudi'),
#               ('Email Address', ''),
#               ('Company', 'Stealth Mode Startup Company'),
#               ('Position', 'Founder'),
#               ('Connected On', '04-Jul-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vikram'),
#               ('Last Name', 'Kamboj'),
#               ('Email Address', ''),
#               ('Company', 'Microsoft'),
#               ('Position', 'Senior Data Scientist'),
#               ('Connected On', '20-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rishi M'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Altus Health Care Solutions'),
#               ('Position', 'Marketing and Operations Manager'),
#               ('Connected On', '18-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anil'),
#               ('Last Name', 'Reddy'),
#               ('Email Address', ''),
#               ('Company', 'Rkinformatics pvt ltd'),
#               ('Position', 'It recruiter'),
#               ('Connected On', '15-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Selvakumar'),
#               ('Last Name', 'Gnanavel'),
#               ('Email Address', ''),
#               ('Company', 'Muthayammal College of Arts & Science'),
#               ('Position', 'Assistant Professor of Computer Science'),
#               ('Connected On', '15-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Tava'),
#               ('Last Name', 'Manggai'),
#               ('Email Address', ''),
#               ('Company',
#                'Malaysian Communications and Multimedia Commission'),
#               ('Position', 'Head, Talent Management'),
#               ('Connected On', '13-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. F.A.K'),
#               ('Last Name', '(Noble)'),
#               ('Email Address', ''),
#               ('Company', 'Noble Transformation Hub (Ai)'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '12-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Roshini'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Aram Visas'),
#               ('Position', 'Senior Immigration Consultant'),
#               ('Connected On', '10-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vetrichelvan'),
#               ('Last Name', 'Dhanasekaran'),
#               ('Email Address', ''),
#               ('Company', 'Indian Institute of Technology, Madras'),
#               ('Position', 'Masters Student'),
#               ('Connected On', '08-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'C R'),
#               ('Last Name', 'LAKSHMI'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Wasim'),
#               ('Last Name', 'Fyrose'),
#               ('Email Address', ''),
#               ('Company', 'Walmart Global Tech India'),
#               ('Position', 'Software Engineer III'),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jay'),
#               ('Last Name', 'Charole'),
#               ('Email Address', ''),
#               ('Company', 'Zep Analytics'),
#               ('Position', 'Data Analyst and Business Developer'),
#               ('Connected On', '07-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Venkatesh'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Zoho'),
#               ('Position', 'Member Technical Staff'),
#               ('Connected On', '05-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rakesh'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst(iOS)'),
#               ('Connected On', '03-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'vinoth'),
#               ('Last Name', 'kumar'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Training Analyst'),
#               ('Connected On', '01-Jun-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Haneef'),
#               ('Last Name', 'Shaik'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '31-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Atul'),
#               ('Last Name', 'Batra'),
#               ('Email Address', ''),
#               ('Company', 'Algonomy'),
#               ('Position', 'CTO'),
#               ('Connected On', '25-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yiqun'),
#               ('Last Name', 'Hu'),
#               ('Email Address', ''),
#               ('Company', 'NTUC Enterprise Co-operative Limited'),
#               ('Position', 'Chief Data Officer'),
#               ('Connected On', '25-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abishek'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'HSBC'),
#               ('Position', 'Data Scientist - FinOps'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Chris'),
#               ('Last Name', 'Hopkins'),
#               ('Email Address', ''),
#               ('Company', 'Evolution Recruitment Solutions, USA'),
#               ('Position', 'Vice President USA'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Madhav'),
#               ('Last Name', 'Didolkar'),
#               ('Email Address', ''),
#               ('Company', 'Shyena Tech Yarns Pvt Ltd'),
#               ('Position', 'Director - Business Development'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Santhosh Sivan'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Data Science Research Scholar'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Archna'),
#               ('Last Name', 'Wadhwa'),
#               ('Email Address', ''),
#               ('Company', 'Analytics Saves at Work'),
#               ('Position', 'Founder and CEO'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sharala'),
#               ('Last Name', 'Axryd'),
#               ('Email Address', ''),
#               ('Company', 'The Center of Applied Data Science'),
#               ('Position', 'Founder and Chief Executive Officer'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sunil'),
#               ('Last Name', 'David'),
#               ('Email Address', ''),
#               ('Company', 'TagBox'),
#               ('Position', 'Advisor'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mario'),
#               ('Last Name', 'Cartia'),
#               ('Email Address', ''),
#               ('Company', 'Freelance'),
#               ('Position', 'Consultant & Technology Evangelist'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prem'),
#               ('Last Name', 'Rishi R'),
#               ('Email Address', ''),
#               ('Company', 'LTI - Larsen & Toubro Infotech'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jason Tamara'),
#               ('Last Name', 'Widjaja'),
#               ('Email Address', ''),
#               ('Company', 'MSD'),
#               ('Position', 'Director of Artificial Intelligence'),
#               ('Connected On', '24-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prabhjot'),
#               ('Last Name', 'Singh Aman'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'ServiceNow Developer'),
#               ('Connected On', '23-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Manoj Kumar'),
#               ('Last Name', 'Patel'),
#               ('Email Address', ''),
#               ('Company', 'HSIN'),
#               ('Position', 'Manager - Technology Services '),
#               ('Connected On', '20-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Suhas'),
#               ('Last Name', 'Kudekar'),
#               ('Email Address', ''),
#               ('Company', 'Synechron'),
#               ('Position', 'Specialist - Technology'),
#               ('Connected On', '11-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Joel'),
#               ('Last Name', 'Andrews Jeyakumar'),
#               ('Email Address', ''),
#               ('Company', 'CGI'),
#               ('Position', 'Associate Software Engineer'),
#               ('Connected On', '11-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayachandran'),
#               ('Last Name', 'J'),
#               ('Email Address', ''),
#               ('Company', 'Tata Consultancy Services'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '09-May-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayasurya'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'Actify Data Labs'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '23-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abinesh Siva'),
#               ('Last Name', 'Manikandan J R'),
#               ('Email Address', ''),
#               ('Company', 'IELEKTRON TECHNOLOGIES PVT. LTD.'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '13-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mohit'),
#               ('Last Name', 'Bhat'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Analyst'),
#               ('Connected On', '13-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dr. X .Agnello'),
#               ('Last Name', 'J Naveen'),
#               ('Email Address', ''),
#               ('Company',
#                'THANTHAI ROEVER INSTITUTE OF AGRICULTURE AND RURAL DEVELOPMENT, PERAMBALUR'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '12-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'siya'),
#               ('Last Name', 'ram'),
#               ('Email Address', ''),
#               ('Company', 'Self-Employed'),
#               ('Position', 'Information Technology'),
#               ('Connected On', '04-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'k'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '04-Apr-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ragupathi'),
#               ('Last Name', 'Thangavel'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '17-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sujith'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '16-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dazil'),
#               ('Last Name', 'Fernandez'),
#               ('Email Address', ''),
#               ('Company', 'Success Enablers India'),
#               ('Position', 'Founder and Principal Consultant'),
#               ('Connected On', '15-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sampathkumar'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '09-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'E'),
#               ('Last Name', 'Sundar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Mar-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mani kandan'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', 'DXC Technology'),
#               ('Position', 'Associate professional application developer'),
#               ('Connected On', '22-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Manikandan'),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Vestige Marketing Pvt. Ltd.'),
#               ('Position', 'Entrepreneur'),
#               ('Connected On', '16-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nambirajan'),
#               ('Last Name', 'R S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '15-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'DHANAPRIYA'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '15-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Naman'),
#               ('Last Name', 'Tripathi'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '10-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ashwini'),
#               ('Last Name', 'Jha'),
#               ('Email Address', ''),
#               ('Company', 'UBS'),
#               ('Position', 'Associate Director - Data Science'),
#               ('Connected On', '06-Feb-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Stanley'),
#               ('Last Name', 'Kapil dev'),
#               ('Email Address', ''),
#               ('Company', 'Paytm'),
#               ('Position', 'Area Sales Manager'),
#               ('Connected On', '31-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Om'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nivetha'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '27-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Thiru'),
#               ('Last Name', 'Varangan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Harsha'),
#               ('Last Name', 'vardhan'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Scholar Trainee'),
#               ('Connected On', '22-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rexson'),
#               ('Last Name', 'Epiron'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '21-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Suyash'),
#               ('Last Name', 'Rastogi'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Consultant'),
#               ('Connected On', '20-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ruthsan'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'OptiSol Business Solutions'),
#               ('Position', 'Full Stack Developer'),
#               ('Connected On', '18-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vinod'),
#               ('Last Name', '.'),
#               ('Email Address', ''),
#               ('Company', "BYJU'S"),
#               ('Position', 'Operation executive'),
#               ('Connected On', '15-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MUHIL'),
#               ('Last Name', 'ARASAN'),
#               ('Email Address', ''),
#               ('Company', 'Merkle'),
#               ('Position', 'Associate Analyst'),
#               ('Connected On', '15-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Dalal'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '12-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'RITESH'),
#               ('Last Name', 'DANGADE'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science & Business Analytics'),
#               ('Connected On', '07-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vaibhav'),
#               ('Last Name', 'Oza'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst'),
#               ('Connected On', '07-Jan-22'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Saurabh'),
#               ('Last Name', 'Anand'),
#               ('Email Address', ''),
#               ('Company', 'Wipro Technologies '),
#               ('Position', 'Senior Software Developer'),
#               ('Connected On', '30-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Utkarsh'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '27-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Christopher Immanuel'),
#               ('Last Name', 'Prince P J'),
#               ('Email Address', ''),
#               ('Company', 'EXL Health'),
#               ('Position', 'Data Analyst Intern'),
#               ('Connected On', '24-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Madhumitha'),
#               ('Last Name', 'Marsaleen'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte Consulting'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '18-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Gayathri'),
#               ('Last Name', 'Sakthivel'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '18-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'CLINTAN '),
#               ('Last Name', 'CYRIL A'),
#               ('Email Address', ''),
#               ('Company', 'Worksbot Applications Private Limited'),
#               ('Position', 'Machine Learning Engineer'),
#               ('Connected On', '17-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SUDHARSHINI'),
#               ('Last Name', 'B'),
#               ('Email Address', ''),
#               ('Company', 'REGex Software Services'),
#               ('Position', 'MEARN SUMMER INTERN'),
#               ('Connected On', '13-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sanant'),
#               ('Last Name', 'Sampathkumar'),
#               ('Email Address', ''),
#               ('Company', 'Vista'),
#               ('Position', 'Data Product Manager'),
#               ('Connected On', '12-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dhivyadharshni'),
#               ('Last Name', 'Natarajan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '12-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'karthik'),
#               ('Last Name', 's'),
#               ('Email Address', ''),
#               ('Company', 'Zoho Corporation'),
#               ('Position', 'Member Of Technical Staff'),
#               ('Connected On', '09-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rajesh'),
#               ('Last Name', 'Kannan M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Harish'),
#               ('Last Name', 'Dornal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Hariharasudhan'),
#               ('Last Name', 'D'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Intern'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aneesa'),
#               ('Last Name', 'Sumaira'),
#               ('Email Address', ''),
#               ('Company', 'COMMUNITY FOUNDATION FOR CHILDREN AND AGING'),
#               ('Position', 'Communication - Human Resource Executive'),
#               ('Connected On', '08-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhiraj'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '04-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Danish'),
#               ('Last Name', 'Ahmed Jaffery'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Learning & Development Specialist'),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shobhit'),
#               ('Last Name', 'Srivastava'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sreerag'),
#               ('Last Name', 'M Surendran'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Operation Executive '),
#               ('Connected On', '03-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ram'),
#               ('Last Name', 'Kishore'),
#               ('Email Address', ''),
#               ('Company', 'Ganit Inc.'),
#               ('Position', 'Data Analyst - Intern'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anuj'),
#               ('Last Name', 'Jain'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abishekraj'),
#               ('Last Name', 'Vinayagar Gnanasambandam'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'VIPIN'),
#               ('Last Name', 'SHUKLA'),
#               ('Email Address', ''),
#               ('Company', 'Impetus'),
#               ('Position', 'Senior Software Engineer'),
#               ('Connected On', '02-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Varshini'),
#               ('Last Name', 'Kuppusami '),
#               ('Email Address', ''),
#               ('Company', 'Bosch Global Software Technologies'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '01-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Samit'),
#               ('Last Name', 'Saxena'),
#               ('Email Address', ''),
#               ('Company', 'Quantiphi'),
#               ('Position', 'Senior Machine Learning Engineer'),
#               ('Connected On', '01-Dec-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'HARI'),
#               ('Last Name', 'UNNIKRISHNAN'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'VIMAL'),
#               ('Last Name', 'S E'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bharat'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Dinesh'),
#               ('Last Name', 'Shivakumar'),
#               ('Email Address', ''),
#               ('Company', 'IBM India Private Limited'),
#               ('Position', 'Service Support Manager'),
#               ('Connected On', '30-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Navjot'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '29-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prabhu'),
#               ('Last Name', 'Sarathy'),
#               ('Email Address', ''),
#               ('Company', 'Zoho Corporation'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '29-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Marivignesh '),
#               ('Last Name', 'N'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Engineer'),
#               ('Connected On', '28-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Anand'),
#               ('Last Name', 'Nagar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '28-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MD SHARIQUE'),
#               ('Last Name', 'BEG'),
#               ('Email Address', ''),
#               ('Company', 'Tata Consultancy Services'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '27-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yawar'),
#               ('Last Name', 'Siddiqui'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '27-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shalvi'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kamalakannan'),
#               ('Last Name', 'T'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sri'),
#               ('Last Name', 'Hari'),
#               ('Email Address', ''),
#               ('Company', 'IN-D - Power of AI'),
#               ('Position', 'R and D engineer trainee'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shaji'),
#               ('Last Name', 'Mathew'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Executive Vice President'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Hari'),
#               ('Last Name', 'Bhagirath'),
#               ('Email Address', ''),
#               ('Company', 'Vuram'),
#               ('Position', 'Corporate Communications'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arun'),
#               ('Last Name', 'Raja'),
#               ('Email Address', ''),
#               ('Company', 'SkyPoint Cloud'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Devang'),
#               ('Last Name', 'Mathur'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Muthu Periyaval'),
#               ('Last Name', 'G S'),
#               ('Email Address', ''),
#               ('Company', 'Mu Sigma Inc.'),
#               ('Position', 'Decision Scientist '),
#               ('Connected On', '26-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Preethi'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', 'Reliance Jio'),
#               ('Position', 'Manager - IT IRM & Cyber Security EPS&F'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Adarsh'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Divyanshu'),
#               ('Last Name', 'Kuksal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sumit Shankar'),
#               ('Last Name', 'Das'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Technical Lead - Oracle Integration Practice'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shambhavi'),
#               ('Last Name', 'Shruti'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sai Aishwarya'),
#               ('Last Name', 'Vernekar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Anand'),
#               ('Email Address', ''),
#               ('Company', 'Microsoft'),
#               ('Position', 'Software Engineer II (Azure Redis Cache)'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Priyansh'),
#               ('Last Name', 'Acharya'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Enayat Haider (PRINCE2,Cybersecurity,'),
#               ('Last Name', 'AWS-Cloud,ITIL,CCNP,B.Tech,MBA-IT)'),
#               ('Email Address', ''),
#               ('Company', 'Wipro Limited'),
#               ('Position', 'Infrastructure Project Manager'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aditi'),
#               ('Last Name', 'Agrawal'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sai Ramcharan'),
#               ('Last Name', 'Tangirala'),
#               ('Email Address', ''),
#               ('Company', 'KPMG Global Services (KGS)'),
#               ('Position', 'Associate Consultant'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rushabh'),
#               ('Last Name', 'Shah'),
#               ('Email Address', ''),
#               ('Company', 'PowerSchool'),
#               ('Position', 'Software Engineer II'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhimanyu'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'TELUS International'),
#               ('Position', 'Senior Applications Developer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Apoorva'),
#               ('Last Name', 'Singh'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Strategy Analyst | India Market Unit'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shabutheen'),
#               ('Last Name', 'Basha'),
#               ('Email Address', 'shabutheenbasha@outlook.com'),
#               ('Company', 'Subex'),
#               ('Position', 'Data Analyst - Lead'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Divya Harish'),
#               ('Last Name', 'Kodandera'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Principal Consultant - Learning'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mohan'),
#               ('Last Name', 'Ramachandran'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Technology Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhupinder Singh'),
#               ('Last Name', 'Chawla'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Group Project Manager'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Nishchal'),
#               ('Last Name', 'Sharan'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'DevOps Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Monika'),
#               ('Last Name', 'Ashok Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys Ltd'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yash'),
#               ('Last Name', 'Narang'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Praveenraaj'),
#               ('Last Name', 'Shanmugam'),
#               ('Email Address', ''),
#               ('Company', 'Cloudside Technologies'),
#               ('Position', 'Data Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Karthick'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'AT&T'),
#               ('Position', 'Senior Associate'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhinandan'),
#               ('Last Name', 'Jain'),
#               ('Email Address', 'abhinandan170398@gmail.com'),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer/Business Analyst '),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Muthu'),
#               ('Last Name', 'Kumar'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Application Development Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sanjeeda'),
#               ('Last Name', 'Yasmeen'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ragavan'),
#               ('Last Name', 'S T'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Senior Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kavin'),
#               ('Last Name', 'Saravanan'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shrihari'),
#               ('Last Name', 'Ravichandran'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini Engineering'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Swati'),
#               ('Last Name', 'Talwar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Associate Consultant'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'ATUL'),
#               ('Last Name', 'AKASH'),
#               ('Email Address', ''),
#               ('Company', 'Deloitte'),
#               ('Position', 'Analyst'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prasanth'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhumi'),
#               ('Last Name', 'Tiwari'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Associate Lead HR- Employee Relations'),
#               ('Connected On', '25-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'Ronkhede'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer - Data Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Cibisasidharan'),
#               ('Last Name', 'ShanmugaSundaram'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhayyasaheb'),
#               ('Last Name', 'Gaikwad'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Badri Narayanan'),
#               ('Last Name', 'C V'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Systems Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SUBHAJIT'),
#               ('Last Name', 'SINHA'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '24-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Venkataraman'),
# ...
#  OrderedDict([('First Name', 'Azmal'),
#               ('Last Name', 'Ahamed'),
#               ('Email Address', ''),
#               ('Company', 'Aelum Consulting - ServiceNow Premier Partner'),
#               ('Position', 'Business Analyst'),
#               ('Connected On', '10-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'MUTHULASKMI'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Daya Anandhi'),
#               ('Last Name', 'Jayaraman'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jo-Anna'),
#               ('Last Name', 'Elizabeth J'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Varun'),
#               ('Last Name', 'Reddy'),
#               ('Email Address', ''),
#               ('Company', 'INNODATATICS * Innovation | Data | Analytics'),
#               ('Position',
#                'Manager- Analytics & Business Development (India)'),
#               ('Connected On', '06-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SHARON'),
#               ('Last Name', 'SAM S'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Student'),
#               ('Connected On', '02-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Yokeshwaran '),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', 'Learn and Build'),
#               ('Position', 'Summer Intern'),
#               ('Connected On', '02-Nov-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Saravanan'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '24-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sagar'),
#               ('Last Name', 'Sharma'),
#               ('Email Address', ''),
#               ('Company', 'Altametrics'),
#               ('Position', 'Datacenter Administrator'),
#               ('Connected On', '14-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'ranjani'),
#               ('Last Name', 'balasubramanian'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '13-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Gyan Prakash '),
#               ('Last Name', 'Konhar'),
#               ('Email Address', ''),
#               ('Company', 'Tiger Analytics'),
#               ('Position', 'Data Science - Analyst'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vissweswaran'),
#               ('Last Name', 'C'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science and Business Analystics Intern'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SATHEES'),
#               ('Last Name', 'KUMAR'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Test Analyst'),
#               ('Connected On', '04-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sujitha'),
#               ('Last Name', 'Rajasekaran'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '02-Oct-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sachin'),
#               ('Last Name', 'Isravel V'),
#               ('Email Address', ''),
#               ('Company', 'LetsGrowMore'),
#               ('Position', 'Data Science Intern'),
#               ('Connected On', '29-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'SASIDHARAN'),
#               ('Last Name', 'C '),
#               ('Email Address', ''),
#               ('Company', 'AstraZeneca'),
#               ('Position', 'Engineer'),
#               ('Connected On', '29-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '27-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Amit'),
#               ('Last Name', 'Vanjode'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '27-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Sumit'),
#               ('Last Name', 'Bhomia'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '23-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Ramya'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', 'adarsh knitwear pvt ltd'),
#               ('Position', 'Management Intern'),
#               ('Connected On', '22-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arnab'),
#               ('Last Name', 'Goswami'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '18-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aniket'),
#               ('Last Name', 'Chatterjee'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Systems Engineer'),
#               ('Connected On', '18-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jemimah'),
#               ('Last Name', 'Kandaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Eugene'),
#               ('Last Name', 'Kingsley'),
#               ('Email Address', ''),
#               ('Company', 'Kissflow'),
#               ('Position', 'Technical Solution Specialist'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'Selvaraj PhD'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '16-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shivani'),
#               ('Last Name', 'Sharma'),
#               ('Email Address', ''),
#               ('Company', 'Areteans'),
#               ('Position', 'Senior Consultant QA'),
#               ('Connected On', '05-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Arjun'),
#               ('Last Name', 'V S'),
#               ('Email Address', ''),
#               ('Company', 'Mila - Quebec Artificial Intelligence Institute'),
#               ('Position', 'Student Researcher'),
#               ('Connected On', '03-Sep-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shweta'),
#               ('Last Name', 'Hooda'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Software Developer'),
#               ('Connected On', '28-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'simran'),
#               ('Last Name', 'sahu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '28-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aashi'),
#               ('Last Name', 'Jain'),
#               ('Email Address', ''),
#               ('Company', 'Accenture'),
#               ('Position', 'Application Development Analyst'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pratiksha'),
#               ('Last Name', 'Govindwar'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vanishree'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys Ltd'),
#               ('Position', 'Learning & Development Associate'),
#               ('Connected On', '27-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aishwariya'),
#               ('Last Name', 'Vijaya kumar'),
#               ('Email Address', ''),
#               ('Company', 'IBM'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '26-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Deepak'),
#               ('Last Name', 'Shukla'),
#               ('Email Address', ''),
#               ('Company', 'Morningstar'),
#               ('Position', 'Software Engineer'),
#               ('Connected On', '26-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Vivek'),
#               ('Last Name', 'Krishna'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '13-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Surya'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '10-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Abhishek'),
#               ('Last Name', 'Nair'),
#               ('Email Address', ''),
#               ('Company', 'Network Intelligence '),
#               ('Position', 'Senior Cybersecurity Analyst'),
#               ('Connected On', '10-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pravalika'),
#               ('Last Name', 'Salina'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'System Engineer'),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Kaviyabharathi '),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '03-Aug-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Prashant'),
#               ('Last Name', 'Pandey'),
#               ('Email Address', ''),
#               ('Company', 'Coal India Limited'),
#               ('Position', 'Management Trainee'),
#               ('Connected On', '15-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Basila Fathima'),
#               ('Last Name', 'Babu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '10-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Aparna '),
#               ('Last Name', 'Pappu'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior Associate Learning and Development '),
#               ('Connected On', '08-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Amoda'),
#               ('Last Name', 'S N'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Senior System Engineer'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Bhavna'),
#               ('Last Name', 'Bhardwaj'),
#               ('Email Address', ''),
#               ('Company', 'UKG'),
#               ('Position', 'Senior Talent Development Consultant'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Rohit'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'Infosys'),
#               ('Position', 'Operations Executive'),
#               ('Connected On', '01-Jul-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Shivani'),
#               ('Last Name', 'Selvaraj'),
#               ('Email Address', ''),
#               ('Company', 'Cognizant'),
#               ('Position', 'Programmer'),
#               ('Connected On', '31-May-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jaisurya'),
#               ('Last Name', 'Narayanan M'),
#               ('Email Address', ''),
#               ('Company', 'Poshmark'),
#               ('Position', 'Software Engineer I Web Applications'),
#               ('Connected On', '27-May-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Auxiliya'),
#               ('Last Name', 'C'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '14-Apr-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', ''),
#               ('Last Name', ''),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '01-Apr-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Mark'),
#               ('Last Name', 'Stoddart'),
#               ('Email Address', ''),
#               ('Company', 'Bali Dyslexia Foundation '),
#               ('Position', 'Ambassador'),
#               ('Connected On', '29-Mar-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Pavithran'),
#               ('Last Name', 'Murali'),
#               ('Email Address', ''),
#               ('Company', 'Medtronic'),
#               ('Position', 'Therapy Development Specialist- TAVR'),
#               ('Connected On', '28-Mar-21'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', "BYJU'S"),
#               ('Position', 'Academic Specialist'),
#               ('Connected On', '17-Nov-20'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Syed'),
#               ('Last Name', 'Ms'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '19-Jul-20'),
#               ('Location', None)]),
#  OrderedDict([('First Name', 'Jayaprakash'),
#               ('Last Name', 'Ravichandran '),
#               ('Email Address', ''),
#               ('Company', 'Guardian Life'),
#               ('Position', 'Associate'),
#               ('Connected On', '06-Apr-20'),
#               ('Location', None)])]

# %%
import nltk
nltk.download('stopwords')
from nltk.metrics.distance import jaccard_distance
from nltk.corpus import stopwords # nltk.download('stopwords')
from cluster import HierarchicalClustering # pip install cluster
import os
CSV_FILE = os.path.join('Connections.csv')

# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

# Adjust sample size as needed to reduce the runtime of the
# nested loop that invokes the DISTANCE function
SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]
    contacts = contacts[:SAMPLE_SIZE]
    
    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', '|', ',', ' & ']

    # Normalize and/or replace known abbreviations
    # and build up a list of common titles.

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for separator in separators:
            for title in titles:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator) if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
            
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]

    # Round up contacts who are in these clusters and group them together
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('{0} {1}.'.format(
                        contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts, clusters

def get_descriptive_terms(titles):
    flatten = lambda l: [item for sublist in l for item in sublist]
    title_words = flatten([title.split() for title in titles])
    filtered_words = [word for word in title_words \
                      if word not in stopwords.words('english')]
    counter = Counter(filtered_words)
    descriptive_terms = counter.most_common(2)
    # Get the most common title words from a cluster, ignoring singletons
    descriptive_terms = [t[0] for t in descriptive_terms if t[1] > 1]
    return descriptive_terms


def display_output(clustered_contacts, clusters):    
    for title_cluster in clusters:
        descriptive_terms = get_descriptive_terms(title_cluster)
        common_titles_heading = 'Common Titles: ' + ', '.join((t for t in title_cluster))
        descriptive_terms_heading =  'Descriptive Terms: ' + ', '.join((t for t in descriptive_terms))
        
        print(common_titles_heading)
        print(descriptive_terms_heading)
        print('-' * 70)
        #print(title_cluster)
        #print(clustered_contacts)
        print('\n'.join(clustered_contacts[tuple(title_cluster)]))
        print()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
out_file
# Out:
# <_io.TextIOWrapper name='sample.json' mode='w' encoding='UTF-8'>

# %%
clustered_contacts
# Out:
# {('Associate Director - Data Science',
#   'Director - Data Analytics'): ['Ritesh A.', 'Ashwini J.'],
#  ('Associate Professor',
#   'Associate',
#   'Associate Consultant'): ['Dr. Selva Rani B.',
#   'Sai Ramcharan T.',
#   'Swati T.',
#   'Jayaprakash R.'],
#  ('Chief Technology Officer',
#   'Chief Data Officer',
#   'Chief Executive Officer'): ['Atul B.',
#   'Yiqun H.',
#   'Archna W.',
#   'Sharala A.'],
#  ('Consultant', 'Principal Consultant'): ['Mario C.', 'Dazil F.'],
#  ('Customer Facing Data Scientist',
#   'Data Scientist',
#   'Senior Data Scientist'): ['Austin C.',
#   'Vikram K.',
#   'Dr. F.A.K (.',
#   'Abinesh Siva M.',
#   'Varshini K.',
#   'Arun R.'],
#  ('Data Analytics Intern ',
#   'Data Analyst',
#   'Data Analyst - Intern',
#   'Data Analyst Intern'): ['Mihika L.',
#   'Jay C.',
#   'Jayasurya V.',
#   'Christopher Immanuel P.',
#   'Madhumitha M.',
#   'Ram K.'],
#  ('Data Science Partner',
#   'Data Science',
#   'Data Science Intern',
#   'Data Analyst - Lead',
#   'Data Science - Analyst'): ['Andrew Weida L.',
#   'RITESH D.',
#   'Shabutheen B.',
#   'Gyan Prakash  K.',
#   'Vissweswaran C.',
#   'Sachin I.'],
#  ('Data Science Research Scholar', 'Research Scholar'): ['Indumathi P.',
#   'Santhosh Sivan A.'],
#  ('Development Specialist',
#   'Development',
#   'Development Associate'): ['Danish A.', 'Vanishree S.', 'Aparna  P.'],
#  ('Digital Marketing Specialist', 'Digital Specialist Engineer'): ['sowmya s.',
#   'Vishal S.'],
#  ('Director of Artificial Intelligence',
#   'Artificial Intelligence',
#   'Artificial Intelligence Engineer'): ['AYUSH G.',
#   'Ritesh A.',
#   'Jason Tamara W.'],
#  ('Executive', 'Operations Executive'): ['Padmanaban  T.',
#   'Amit V.',
#   'Vivek K.',
#   'Rohit R.'],
#  ('Executive Vice President', 'Vice President USA'): ['Chris H.', 'Shaji M.'],
#  ('Group Project Manager',
#   'Infrastructure Project Manager'): ['Enayat Haider (PRINCE2,Cybersecurity, A.', 'Bhupinder Singh C.'],
#  ('Machine Learning Engineer',
#   'Senior Machine Learning Engineer'): ['CLINTAN  C.', 'Samit S.'],
#  ('Member Of Technical Staff', 'Member Technical Staff'): ['Venkatesh S.',
#   'karthik s.'],
#  ('Operation Executive', 'Senior Operation Executive '): ['Abhishek S.',
#   'Sreerag M.'],
#  ('Programmer',
#   'Programmer Analyst',
#   'Training Analyst',
#   'Test Analyst',
#   'Technology Analyst',
#   'Strategy Analyst',
#   'Business Analyst',
#   'Analyst',
#   'Associate Analyst'): ['Godly P.',
#   'vinoth k.',
#   'Mohit B.',
#   'MUHIL A.',
#   'Vaibhav O.',
#   'Apoorva S.',
#   'Mohan R.',
#   'Abhinandan J.',
#   'ATUL A.',
#   'Chandra Sekhar M.',
#   'Azmal A.',
#   'SATHEES K.',
#   'Shivani S.'],
#  ('Senior Analyst', 'Senior Cybersecurity Analyst'): ['Ragavan S.',
#   'Abhishek N.'],
#  ('Senior Applications Developer',
#   'Senior Software Developer',
#   'Software Developer'): ['Sathish K.',
#   'Saurabh A.',
#   'Abhimanyu S.',
#   'Shweta H.'],
#  ('Senior Associate', 'Senior Associate Learning'): ['Karthick R.',
#   'Aparna  P.'],
#  ('Senior Systems Engineer',
#   'Systems Engineer',
#   'Systems Engineer '): ['Divyanshu K.', 'Cibisasidharan S.', 'Bhayyasaheb G.', 'Badri Narayanan C.', 'Harsh S.', 'Amarnath M.', 'Aniket C.'],
#  ('Senior Talent Development Consultant',
#   'Senior Immigration Consultant',
#   'Senior Consultant',
#   'Senior Consultant QA'): ['Roshini S.',
#   'Suyash R.',
#   'Shivani S.',
#   'Bhavna B.'],
#  ('Software Engineer III',
#   'Software Engineer II (Azure Redis Cache)',
#   'Software Engineer II',
#   'Senior Software Engineer',
#   'Associate Software Engineer',
#   'Software Engineer'): ['Jonathan B.',
#   'SHIV RAM S.',
#   'Wasim F.',
#   'Prem R.',
#   'Joel A.',
#   'VIPIN S.',
#   'Rohit A.',
#   'Rushabh S.',
#   'Shrihari R.',
#   'SIVARAJ D.',
#   'Deepak S.'],
#  ('Student Researcher', 'Masters Student', 'Student'): ['Vetrichelvan D.',
#   'SHARON S.',
#   'Arjun V.'],
#  ('Summer Intern', 'Intern', 'Management Intern'): ['Hariharasudhan D.',
#   'Yokeshwaran  G.',
#   'Ramya P.'],
#  ('System Engineer - Data Engineer',
#   'Senior System Engineer',
#   'System Engineer',
#   'Test Engineer',
#   'DevOps Engineer',
#   'Data Engineer',
#   'Engineer'): ['Haneef S.',
#   'Jayachandran J.',
#   'Ragupathi T.',
#   'Utkarsh P.',
#   'Harish D.',
#   'Abhiraj S.',
#   'Shobhit S.',
#   'Anuj J.',
#   'Abishekraj V.',
#   'HARI U.',
#   'Navjot S.',
#   'Prabhu S.',
#   'Marivignesh  N.',
#   'Anand N.',
#   'MD SHARIQUE B.',
#   'Yawar S.',
#   'Shalvi S.',
#   'Kamalakannan T.',
#   'Devang M.',
#   'Adarsh K.',
#   'Shambhavi S.',
#   'Sai Aishwarya V.',
#   'Priyansh A.',
#   'Aditi A.',
#   'Nishchal S.',
#   'Monika A.',
#   'Yash N.',
#   'Praveenraaj S.',
#   'Abhinandan J.',
#   'Sanjeeda Y.',
#   'Kavin S.',
#   'Prasanth S.',
#   'Rohit R.',
#   'SUBHAJIT S.',
#   'Abhishek V.',
#   'Niraj M.',
#   'Sangamesh U.',
#   'Jerome D.',
#   'Ranjithkumar K.',
#   'SASIDHARAN C.',
#   'Sumit B.',
#   'Arnab G.',
#   'simran s.',
#   'Pratiksha G.',
#   'Aishwariya V.',
#   'Surya A.',
#   'Pravalika S.',
#   'Kaviyabharathi  S.',
#   'Basila Fathima B.',
#   'Amoda S.']}

# %%
def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = get_descriptive_terms(titles)

        json_output['children'].append({'name' : ', '.join(descriptive_terms)[:30], 'children' : [ {'name' : c} for c in clustered_contacts[titles] ] } )
        with open("sample.json", "w") as out_file:
            json.dump(json_output,out_file,indent=1)
            out_file.close()
    
clustered_contacts, clusters = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts, clusters)
write_d3_json_output(clustered_contacts)
# Out:
# Common Titles: Group Project Manager, Infrastructure Project Manager
# Descriptive Terms: Project, Manager
# ----------------------------------------------------------------------
# Enayat Haider (PRINCE2,Cybersecurity, A.
# Bhupinder Singh C.
#
# Common Titles: Senior Talent Development Consultant, Senior Immigration Consultant, Senior Consultant, Senior Consultant QA
# Descriptive Terms: Senior, Consultant
# ----------------------------------------------------------------------
# Roshini S.
# Suyash R.
# Shivani S.
# Bhavna B.
#
# Common Titles: Consultant, Principal Consultant
# Descriptive Terms: Consultant
# ----------------------------------------------------------------------
# Mario C.
# Dazil F.
#
# Common Titles: Member Of Technical Staff, Member Technical Staff
# Descriptive Terms: Member, Technical
# ----------------------------------------------------------------------
# Venkatesh S.
# karthik s.
#
# Common Titles: Summer Intern, Intern, Management Intern
# Descriptive Terms: Intern
# ----------------------------------------------------------------------
# Hariharasudhan D.
# Yokeshwaran  G.
# Ramya P.
#
# Common Titles: Digital Marketing Specialist, Digital Specialist Engineer
# Descriptive Terms: Digital, Specialist
# ----------------------------------------------------------------------
# sowmya s.
# Vishal S.
#
# Common Titles: Development Specialist, Development, Development Associate
# Descriptive Terms: Development
# ----------------------------------------------------------------------
# Danish A.
# Vanishree S.
# Aparna  P.
#
# Common Titles: Director of Artificial Intelligence, Artificial Intelligence, Artificial Intelligence Engineer
# Descriptive Terms: Artificial, Intelligence
# ----------------------------------------------------------------------
# AYUSH G.
# Ritesh A.
# Jason Tamara W.
#
# Common Titles: Associate Director - Data Science, Director - Data Analytics
# Descriptive Terms: Director, -
# ----------------------------------------------------------------------
# Ritesh A.
# Ashwini J.
#
# Common Titles: Data Science Research Scholar, Research Scholar
# Descriptive Terms: Research, Scholar
# ----------------------------------------------------------------------
# Indumathi P.
# Santhosh Sivan A.
#
# Common Titles: Data Science Partner, Data Science, Data Science Intern, Data Analyst - Lead, Data Science - Analyst
# Descriptive Terms: Data, Science
# ----------------------------------------------------------------------
# Andrew Weida L.
# RITESH D.
# Shabutheen B.
# Gyan Prakash  K.
# Vissweswaran C.
# Sachin I.
#
# Common Titles: Senior Associate, Senior Associate Learning
# Descriptive Terms: Senior, Associate
# ----------------------------------------------------------------------
# Karthick R.
# Aparna  P.
#
# Common Titles: Executive Vice President, Vice President USA
# Descriptive Terms: Vice, President
# ----------------------------------------------------------------------
# Chris H.
# Shaji M.
#
# Common Titles: Operation Executive, Senior Operation Executive
# Descriptive Terms: Operation, Executive
# ----------------------------------------------------------------------
# Abhishek S.
# Sreerag M.
#
# Common Titles: Executive, Operations Executive
# Descriptive Terms: Executive
# ----------------------------------------------------------------------
# Padmanaban  T.
# Amit V.
# Vivek K.
# Rohit R.
#
# Common Titles: Student Researcher, Masters Student, Student
# Descriptive Terms: Student
# ----------------------------------------------------------------------
# Vetrichelvan D.
# SHARON S.
# Arjun V.
#
# Common Titles: Data Analytics Intern , Data Analyst, Data Analyst - Intern, Data Analyst Intern
# Descriptive Terms: Data, Intern
# ----------------------------------------------------------------------
# Mihika L.
# Jay C.
# Jayasurya V.
# Christopher Immanuel P.
# Madhumitha M.
# Ram K.
#
# Common Titles: Senior Analyst, Senior Cybersecurity Analyst
# Descriptive Terms: Senior, Analyst
# ----------------------------------------------------------------------
# Ragavan S.
# Abhishek N.
#
# Common Titles: Programmer, Programmer Analyst, Training Analyst, Test Analyst, Technology Analyst, Strategy Analyst, Business Analyst, Analyst, Associate Analyst
# Descriptive Terms: Analyst, Programmer
# ----------------------------------------------------------------------
# Godly P.
# vinoth k.
# Mohit B.
# MUHIL A.
# Vaibhav O.
# Apoorva S.
# Mohan R.
# Abhinandan J.
# ATUL A.
# Chandra Sekhar M.
# Azmal A.
# SATHEES K.
# Shivani S.
#
# Common Titles: Senior Applications Developer, Senior Software Developer, Software Developer
# Descriptive Terms: Developer, Senior
# ----------------------------------------------------------------------
# Sathish K.
# Saurabh A.
# Abhimanyu S.
# Shweta H.
#
# Common Titles: Chief Technology Officer, Chief Data Officer, Chief Executive Officer
# Descriptive Terms: Chief, Officer
# ----------------------------------------------------------------------
# Atul B.
# Yiqun H.
# Archna W.
# Sharala A.
#
# Common Titles: Software Engineer III, Software Engineer II (Azure Redis Cache), Software Engineer II, Senior Software Engineer, Associate Software Engineer, Software Engineer
# Descriptive Terms: Software, Engineer
# ----------------------------------------------------------------------
# Jonathan B.
# SHIV RAM S.
# Wasim F.
# Prem R.
# Joel A.
# VIPIN S.
# Rohit A.
# Rushabh S.
# Shrihari R.
# SIVARAJ D.
# Deepak S.
#
# Common Titles: Associate Professor, Associate, Associate Consultant
# Descriptive Terms: Associate
# ----------------------------------------------------------------------
# Dr. Selva Rani B.
# Sai Ramcharan T.
# Swati T.
# Jayaprakash R.
#
# Common Titles: System Engineer - Data Engineer, Senior System Engineer, System Engineer, Test Engineer, DevOps Engineer, Data Engineer, Engineer
# Descriptive Terms: Engineer, System
# ----------------------------------------------------------------------
# Haneef S.
# Jayachandran J.
# Ragupathi T.
# Utkarsh P.
# Harish D.
# Abhiraj S.
# Shobhit S.
# Anuj J.
# Abishekraj V.
# HARI U.
# Navjot S.
# Prabhu S.
# Marivignesh  N.
# Anand N.
# MD SHARIQUE B.
# Yawar S.
# Shalvi S.
# Kamalakannan T.
# Devang M.
# Adarsh K.
# Shambhavi S.
# Sai Aishwarya V.
# Priyansh A.
# Aditi A.
# Nishchal S.
# Monika A.
# Yash N.
# Praveenraaj S.
# Abhinandan J.
# Sanjeeda Y.
# Kavin S.
# Prasanth S.
# Rohit R.
# SUBHAJIT S.
# Abhishek V.
# Niraj M.
# Sangamesh U.
# Jerome D.
# Ranjithkumar K.
# SASIDHARAN C.
# Sumit B.
# Arnab G.
# simran s.
# Pratiksha G.
# Aishwariya V.
# Surya A.
# Pravalika S.
# Kaviyabharathi  S.
# Basila Fathima B.
# Amoda S.
#
# Common Titles: Machine Learning Engineer, Senior Machine Learning Engineer
# Descriptive Terms: Machine, Learning
# ----------------------------------------------------------------------
# CLINTAN  C.
# Samit S.
#
# Common Titles: Senior Systems Engineer, Systems Engineer, Systems Engineer
# Descriptive Terms: Systems, Engineer
# ----------------------------------------------------------------------
# Divyanshu K.
# Cibisasidharan S.
# Bhayyasaheb G.
# Badri Narayanan C.
# Harsh S.
# Amarnath M.
# Aniket C.
#
# Common Titles: Customer Facing Data Scientist, Data Scientist, Senior Data Scientist
# Descriptive Terms: Data, Scientist
# ----------------------------------------------------------------------
# Austin C.
# Vikram K.
# Dr. F.A.K (.
# Abinesh Siva M.
# Varshini K.
# Arun R.
